# %%
import pandas as pd
import numpy as np
import time
import os
import glob
import json
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from collections import defaultdict

# %% [markdown]
# ## Configuration

# %%
# Directory where the derived data is stored
DERIVED_DATA_DIR = '../../../data'

# Number of force cells in the robotic leg
N_CELLS = 8

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Prediction of the data from the same experiment

# %%
H3_LEG = 'L' # L|R

features = [H3_LEG + a + m for a in ['Hip', 'Knee'] for m in ['Pos', 'Torque']]
targets = ['F' + str(i + 1) + ax for i in range(N_CELLS) for ax in ['x', 'y', 'z']]

print('Number of features: {}'.format(len(features)))
print('Selected features: {}'.format(features))
print('\n')
print('Number of targets: {}'.format(len(targets)))
print('Selected targets: {}'.format(targets))
# Out:
# Number of features: 4
# Selected features: ['LHipPos', 'LHipTorque', 'LKneePos', 'LKneeTorque']
#
#
# Number of targets: 24
# Selected targets: ['F1x', 'F1y', 'F1z', 'F2x', 'F2y', 'F2z', 'F3x', 'F3y', 'F3z', 'F4x', 'F4y', 'F4z', 'F5x', 'F5y', 'F5z', 'F6x', 'F6y', 'F6z', 'F7x', 'F7y', 'F7z', 'F8x', 'F8y', 'F8z']

# %%
# Scaler to normalize the data
SCALER = MinMaxScaler() # StandardScaler()

# Percentage of the date for the test set
TEST_SIZE = 0.3

# %%
experiments_dirs_path = glob.glob(DERIVED_DATA_DIR + '/*/*')
exp_path = experiments_dirs_path[0]

print('Experiment: ' + exp_path)
# Out:
# Experiment: ../../../data/10032021/1

# %%
# Load targets
targets_df = pd.read_csv(exp_path + '/force_cells_processed.csv')

# Load features
features_df = pd.read_csv(exp_path + '/H3_processed.csv')
# leg_df = pd.read_csv(exp_path + '/leg_processed.csv')
# features_df = pd.concat([exo_df, leg_df], axis=1)

# Drop first row to remove noise in the start of the data recording
targets_df = targets_df.iloc[1:]
features_df = features_df.iloc[1:]
# Drop null values
idx = features_df.notna().all(axis=1)
features_df = features_df.loc[idx]
targets_df = targets_df.loc[idx]
print('Droping {} data points by null features'.format(len(idx[idx == False])))

assert(len(features_df) == len(targets_df))
# Store the final array
targets_arr = targets_df[targets].values
features_arr = features_df[features].values

print('X: {}, Y: {}'.format(features_arr.shape, targets_arr.shape))
# Out:
# Droping 2 data points by null features
# X: (6072, 4), Y: (6072, 24)

# %%
idx_split = int(targets_arr.shape[0] * TEST_SIZE)

X_train = features_arr[:-idx_split, :]
X_test = features_arr[-idx_split:, :]

Y_train = targets_arr[:-idx_split, :]
Y_test = targets_arr[-idx_split:, :]

print('Train -> X: {}, Y: {}'.format(X_train.shape, Y_train.shape))
print('Test -> X: {}, Y: {}'.format(X_test.shape, Y_test.shape))
# Out:
# Train -> X: (4251, 4), Y: (4251, 24)
# Test -> X: (1821, 4), Y: (1821, 24)

# %%
s = SCALER.fit(X_train)

X_train = s.transform(X_train)
X_test = s.transform(X_test)

print('Train -> \n min: {}, \n max: {}, \n mean: {}, \n std: {}\n'.format(np.min(X_train, axis=0), np.max(X_train, axis=0), np.mean(X_train, axis=0), np.std(X_train, axis=0)))
print('Test -> \n min: {}, \n max: {}, \n mean: {}, \n std: {}\n'.format(np.min(X_test, axis=0), np.max(X_test, axis=0), np.mean(X_test, axis=0), np.std(X_test, axis=0)))
# Out:
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43460795 0.4028391  0.22404348 0.45510021],
#  std: [0.33853871 0.23908632 0.29838709 0.27007675]
#
# Test ->
#  min: [1.14338908e-03 1.44560816e-02 4.80148601e-06 2.47788203e-03],
#  max: [0.99984536 1.01702033 0.99921221 1.00004503],
#  mean: [0.44575618 0.40768544 0.23334027 0.44694299],
#  std: [0.34346745 0.24434585 0.30538404 0.27623816]

# %%
# Setup the model with the best parameters
model = RandomForestRegressor(random_state=0, n_jobs=-1, verbose=0)

t_start = time.time()
model.fit(X_train, Y_train)
tr_time = time.time() - t_start
print('Training time: {:.4f}'.format(tr_time))

train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

results = {
    'Train': {
        'MAE': mean_absolute_error(Y_train, train_preds, multioutput='raw_values'),
        'MSE': mean_squared_error(Y_train, train_preds, multioutput='raw_values'),
        'R2': r2_score(Y_train, train_preds, multioutput='raw_values')
    },
    'Test': {
        'MAE': mean_absolute_error(Y_test, test_preds, multioutput='raw_values'),
        'MSE': mean_squared_error(Y_test, test_preds, multioutput='raw_values'),
        'R2': r2_score(Y_test, test_preds, multioutput='raw_values')
    }       
    
}

results_summary = {}
results_summary['Training time'] = tr_time
# Display the score mean and standard deviation of each axis
for subset in ['Train', 'Test']:
    for f, force in enumerate(['Fx', 'Fy', 'Fz']):
        for loss in ['MAE', 'MSE', 'R2']:
            scores = [results[subset][loss][i + f] for i in range(0, N_CELLS * 3, 3)]
            print(' '.join([subset, force, loss]) + ': {:.4f} ± {:.4f}'.format(np.mean(scores), np.std(scores)))
            results_summary[' '.join([subset, force, loss])] = '{:.4f} ± {:.4f}'.format(np.mean(scores), np.std(scores))
# Out:
# Training time: 0.6243
# Train Fx MAE: 0.3248 ± 0.1267
# Train Fx MSE: 0.3407 ± 0.2547
# Train Fx R2: 0.9982 ± 0.0011
# Train Fy MAE: 0.3496 ± 0.2232
# Train Fy MSE: 0.5160 ± 0.5889
# Train Fy R2: 0.9945 ± 0.0031
# Train Fz MAE: 0.3190 ± 0.1284
# Train Fz MSE: 0.3234 ± 0.2479
# Train Fz R2: 0.9982 ± 0.0010
# Test Fx MAE: 1.1975 ± 0.4073
# Test Fx MSE: 5.1875 ± 3.1007
# Test Fx R2: 0.9681 ± 0.0191
# Test Fy MAE: 1.2261 ± 0.7991
# Test Fy MSE: 6.0645 ± 6.0490
# Test Fy R2: 0.9282 ± 0.0350
# Test Fz MAE: 1.2854 ± 0.4892
# Test Fz MSE: 5.8195 ± 2.9215
# Test Fz R2: 0.9603 ± 0.0242

# %%
results_full = defaultdict(list)

for exp_path in experiments_dirs_path:
    print(exp_path)
    # Load targets
    targets_df = pd.read_csv(exp_path + '/force_cells_processed.csv')

    # Load features
    features_df = pd.read_csv(exp_path + '/H3_processed.csv')

    # Drop first row to remove noise in the start of the data recording
    targets_df = targets_df.iloc[1:]
    features_df = features_df.iloc[1:]
    # Drop null values
    idx = features_df.notna().all(axis=1)
    features_df = features_df.loc[idx]
    targets_df = targets_df.loc[idx]
    print('Droping {} data points by null features'.format(len(idx[idx == False])))

    assert(len(features_df) == len(targets_df))
    # Store the final array
    targets_arr = targets_df[targets].values
    features_arr = features_df[features].values

    print('X: {}, Y: {}'.format(features_arr.shape, targets_arr.shape))

    idx_split = int(targets_arr.shape[0] * TEST_SIZE)

    X_train = features_arr[:-idx_split, :]
    X_test = features_arr[-idx_split:, :]

    Y_train = targets_arr[:-idx_split, :]
    Y_test = targets_arr[-idx_split:, :]

    print('Train -> X: {}, Y: {}'.format(X_train.shape, Y_train.shape))
    print('Test -> X: {}, Y: {}'.format(X_test.shape, Y_test.shape))

    s = SCALER.fit(X_train)

    X_train = s.transform(X_train)
    X_test = s.transform(X_test)

    print('Train -> \n min: {}, \n max: {}, \n mean: {}, \n std: {}\n'.format(np.min(X_train, axis=0), np.max(X_train, axis=0), np.mean(X_train, axis=0), np.std(X_train, axis=0)))
    print('Test -> \n min: {}, \n max: {}, \n mean: {}, \n std: {}\n'.format(np.min(X_test, axis=0), np.max(X_test, axis=0), np.mean(X_test, axis=0), np.std(X_test, axis=0)))

    # Setup the model with the best parameters
    model = RandomForestRegressor(random_state=0, n_jobs=-1, verbose=0)

    t_start = time.time()
    model.fit(X_train, Y_train)
    tr_time = time.time() - t_start
    print('Training time: {:.4f}'.format(tr_time))

    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)

    results = {
        'Train': {
            'MAE': mean_absolute_error(Y_train, train_preds, multioutput='raw_values'),
            'MSE': mean_squared_error(Y_train, train_preds, multioutput='raw_values'),
            'R2': r2_score(Y_train, train_preds, multioutput='raw_values')
        },
        'Test': {
            'MAE': mean_absolute_error(Y_test, test_preds, multioutput='raw_values'),
            'MSE': mean_squared_error(Y_test, test_preds, multioutput='raw_values'),
            'R2': r2_score(Y_test, test_preds, multioutput='raw_values')
        }       

    }

    results_summary = {}
    results_summary['Training time'] = tr_time
    # Display the score mean and standard deviation of each axis
    for subset in ['Train', 'Test']:
        for f, force in enumerate(['Fx', 'Fy', 'Fz']):
            for loss in ['MAE', 'MSE', 'R2']:
                scores = [results[subset][loss][i + f] for i in range(0, N_CELLS * 3, 3)]
                s_mean = np.mean(scores)
                s_std = np.std(scores)
                
                print(' '.join([subset, force, loss]) + ': {:.4f} ± {:.4f}'.format(s_mean, s_std))
                results_summary[' '.join([subset, force, loss])] = '{:.4f} ± {:.4f}'.format(s_mean, s_std)
                
                results_full[' '.join([subset, force, loss])].append(s_mean)

    print('\n')
# Out:
# ../../../data/10032021/1
# Droping 2 data points by null features
# X: (6072, 4), Y: (6072, 24)
# Train -> X: (4251, 4), Y: (4251, 24)
# Test -> X: (1821, 4), Y: (1821, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43460795 0.4028391  0.22404348 0.45510021],
#  std: [0.33853871 0.23908632 0.29838709 0.27007675]
#
# Test ->
#  min: [1.14338908e-03 1.44560816e-02 4.80148601e-06 2.47788203e-03],
#  max: [0.99984536 1.01702033 0.99921221 1.00004503],
#  mean: [0.44575618 0.40768544 0.23334027 0.44694299],
#  std: [0.34346745 0.24434585 0.30538404 0.27623816]
#
# Training time: 0.5445
# Train Fx MAE: 0.3248 ± 0.1267
# Train Fx MSE: 0.3407 ± 0.2547
# Train Fx R2: 0.9982 ± 0.0011
# Train Fy MAE: 0.3496 ± 0.2232
# Train Fy MSE: 0.5160 ± 0.5889
# Train Fy R2: 0.9945 ± 0.0031
# Train Fz MAE: 0.3190 ± 0.1284
# Train Fz MSE: 0.3234 ± 0.2479
# Train Fz R2: 0.9982 ± 0.0010
# Test Fx MAE: 1.1975 ± 0.4073
# Test Fx MSE: 5.1875 ± 3.1007
# Test Fx R2: 0.9681 ± 0.0191
# Test Fy MAE: 1.2261 ± 0.7991
# Test Fy MSE: 6.0645 ± 6.0490
# Test Fy R2: 0.9282 ± 0.0350
# Test Fz MAE: 1.2854 ± 0.4892
# Test Fz MSE: 5.8195 ± 2.9215
# Test Fz R2: 0.9603 ± 0.0242
#
#
# ../../../data/16022021/1
# Droping 0 data points by null features
# X: (17907, 4), Y: (17907, 24)
# Train -> X: (12535, 4), Y: (12535, 24)
# Test -> X: (5372, 4), Y: (5372, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43412384 0.35458293 0.21072979 0.46476291],
#  std: [0.33828416 0.22578917 0.29357661 0.21847703]
#
# Test ->
#  min: [ 2.15053665e-03 -1.79131507e-03 -4.41328245e-05  8.29180565e-03],
#  max: [1.00062764 0.97477636 1.00251344 0.99947817],
#  mean: [0.44364495 0.35141866 0.21734941 0.46553829],
#  std: [0.34080707 0.22966446 0.29753343 0.22131009]
#
# Training time: 2.0970
# Train Fx MAE: 0.2353 ± 0.0929
# Train Fx MSE: 0.1494 ± 0.1075
# Train Fx R2: 0.9959 ± 0.0016
# Train Fy MAE: 0.2439 ± 0.1235
# Train Fy MSE: 0.1950 ± 0.1679
# Train Fy R2: 0.9916 ± 0.0037
# Train Fz MAE: 0.2375 ± 0.0946
# Train Fz MSE: 0.1698 ± 0.1081
# Train Fz R2: 0.9971 ± 0.0014
# Test Fx MAE: 0.7567 ± 0.3055
# Test Fx MSE: 1.3488 ± 0.9301
# Test Fx R2: 0.9621 ± 0.0171
# Test Fy MAE: 0.8176 ± 0.4279
# Test Fy MSE: 1.7847 ± 1.5089
# Test Fy R2: 0.8776 ± 0.0951
# Test Fz MAE: 0.7864 ± 0.3405
# Test Fz MSE: 1.5608 ± 1.1635
# Test Fz R2: 0.9729 ± 0.0149
#
#
# ../../../data/16022021/2
# Droping 0 data points by null features
# X: (17875, 4), Y: (17875, 24)
# Train -> X: (12513, 4), Y: (12513, 24)
# Test -> X: (5362, 4), Y: (5362, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43449095 0.37161224 0.20823102 0.45638168],
#  std: [0.33833589 0.23152474 0.29128334 0.21830835]
#
# Test ->
#  min: [ 3.35415287e-05  5.37369825e-04 -3.78449040e-05  1.66975916e-03],
#  max: [0.99881224 0.99563493 0.99975312 0.97466162],
#  mean: [0.44307119 0.3669622  0.21532705 0.4580517 ],
#  std: [0.3412659  0.23494873 0.29498091 0.2202771 ]
#
# Training time: 2.5303
# Train Fx MAE: 0.2922 ± 0.0959
# Train Fx MSE: 0.2828 ± 0.1650
# Train Fx R2: 0.9908 ± 0.0042
# Train Fy MAE: 0.3160 ± 0.1576
# Train Fy MSE: 0.3102 ± 0.2679
# Train Fy R2: 0.9879 ± 0.0047
# Train Fz MAE: 0.2908 ± 0.0982
# Train Fz MSE: 0.2672 ± 0.1555
# Train Fz R2: 0.9926 ± 0.0067
# Test Fx MAE: 2.5390 ± 0.8804
# Test Fx MSE: 17.6885 ± 11.9731
# Test Fx R2: 0.3350 ± 0.4780
# Test Fy MAE: 2.7577 ± 1.4992
# Test Fy MSE: 26.7150 ± 27.0850
# Test Fy R2: -0.6838 ± 2.3916
# Test Fz MAE: 3.2732 ± 1.0460
# Test Fz MSE: 36.0667 ± 39.7134
# Test Fz R2: 0.3780 ± 0.4604
#
#
# ../../../data/16022021/3
# Droping 0 data points by null features
# X: (17914, 4), Y: (17914, 24)
# Train -> X: (12540, 4), Y: (12540, 24)
# Test -> X: (5374, 4), Y: (5374, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43477989 0.38464918 0.20836628 0.45208845],
#  std: [0.34008295 0.23741517 0.29135906 0.22318362]
#
# Test ->
#  min: [ 2.85858449e-04 -4.18370965e-03 -5.76562242e-05  1.21572301e-03],
#  max: [0.99622373 0.99387347 1.00001838 0.99375727],
#  mean: [0.44427282 0.38810592 0.21445763 0.44649503],
#  std: [0.34247854 0.24113255 0.29521547 0.223355  ]
#
# Training time: 2.3301
# Train Fx MAE: 0.3497 ± 0.1193
# Train Fx MSE: 0.2908 ± 0.2011
# Train Fx R2: 0.9904 ± 0.0048
# Train Fy MAE: 0.3916 ± 0.2153
# Train Fy MSE: 0.4441 ± 0.4490
# Train Fy R2: 0.9854 ± 0.0086
# Train Fz MAE: 0.3808 ± 0.1168
# Train Fz MSE: 0.3484 ± 0.1680
# Train Fz R2: 0.9925 ± 0.0055
# Test Fx MAE: 1.0671 ± 0.3676
# Test Fx MSE: 2.4203 ± 1.5550
# Test Fx R2: 0.9115 ± 0.0475
# Test Fy MAE: 1.1608 ± 0.6975
# Test Fy MSE: 3.7644 ± 4.1208
# Test Fy R2: 0.8620 ± 0.1059
# Test Fz MAE: 1.1397 ± 0.4168
# Test Fz MSE: 3.0541 ± 2.0610
# Test Fz R2: 0.9430 ± 0.0372
#
#
# ../../../data/16022021/4
# Droping 0 data points by null features
# X: (17960, 4), Y: (17960, 24)
# Train -> X: (12572, 4), Y: (12572, 24)
# Test -> X: (5388, 4), Y: (5388, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43333446 0.3768022  0.20857692 0.4688421 ],
#  std: [0.33943642 0.22806703 0.29100108 0.21259525]
#
# Test ->
#  min: [-9.78178766e-04 -2.09043125e-03 -4.55507564e-05  1.87263925e-03],
#  max: [1.00057557 0.98408987 1.00504855 0.95998741],
#  mean: [0.44245932 0.37702627 0.21493377 0.46612322],
#  std: [0.34211808 0.23100173 0.29635414 0.21324709]
#
# Training time: 2.0318
# Train Fx MAE: 0.2958 ± 0.0980
# Train Fx MSE: 0.2191 ± 0.1451
# Train Fx R2: 0.9937 ± 0.0033
# Train Fy MAE: 0.3378 ± 0.1565
# Train Fy MSE: 0.3209 ± 0.2183
# Train Fy R2: 0.9845 ± 0.0172
# Train Fz MAE: 0.2766 ± 0.1216
# Train Fz MSE: 0.1848 ± 0.1377
# Train Fz R2: 0.9958 ± 0.0031
# Test Fx MAE: 0.9950 ± 0.3169
# Test Fx MSE: 1.9708 ± 1.1501
# Test Fx R2: 0.9344 ± 0.0267
# Test Fy MAE: 1.2061 ± 0.5947
# Test Fy MSE: 3.6167 ± 2.5109
# Test Fy R2: 0.8033 ± 0.2195
# Test Fz MAE: 1.0983 ± 0.5590
# Test Fz MSE: 2.5930 ± 2.1783
# Test Fz R2: 0.9463 ± 0.0413
#
#
# ../../../data/16022021/5
# Droping 0 data points by null features
# X: (17898, 4), Y: (17898, 24)
# Train -> X: (12529, 4), Y: (12529, 24)
# Test -> X: (5369, 4), Y: (5369, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43540219 0.37998173 0.20820683 0.46324668],
#  std: [0.33979842 0.23213242 0.29100022 0.21798508]
#
# Test ->
#  min: [ 2.00505680e-03  2.02045028e-03 -6.60627955e-05 -3.81035218e-03],
#  max: [0.99742751 0.99558518 1.00300586 0.98299513],
#  mean: [0.44490174 0.38180298 0.21422727 0.45917677],
#  std: [0.34158668 0.23373556 0.29522113 0.21732155]
#
# Training time: 2.1322
# Train Fx MAE: 0.2632 ± 0.1124
# Train Fx MSE: 0.2491 ± 0.2151
# Train Fx R2: 0.9945 ± 0.0036
# Train Fy MAE: 0.2537 ± 0.1254
# Train Fy MSE: 0.1940 ± 0.1495
# Train Fy R2: 0.9925 ± 0.0042
# Train Fz MAE: 0.2238 ± 0.1063
# Train Fz MSE: 0.1544 ± 0.1367
# Train Fz R2: 0.9975 ± 0.0015
# Test Fx MAE: 0.8083 ± 0.3071
# Test Fx MSE: 1.6558 ± 1.1134
# Test Fx R2: 0.9575 ± 0.0272
# Test Fy MAE: 0.8623 ± 0.4666
# Test Fy MSE: 2.1818 ± 1.9707
# Test Fy R2: 0.9184 ± 0.0524
# Test Fz MAE: 0.7500 ± 0.3740
# Test Fz MSE: 1.4064 ± 1.2222
# Test Fz R2: 0.9777 ± 0.0153
#
#
# ../../../data/16022021/6
# Droping 0 data points by null features
# X: (17841, 4), Y: (17841, 24)
# Train -> X: (12489, 4), Y: (12489, 24)
# Test -> X: (5352, 4), Y: (5352, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43658497 0.39263841 0.21020217 0.45594981],
#  std: [0.33906664 0.22553784 0.29273992 0.22524965]
#
# Test ->
#  min: [ 3.39553799e-04  2.06457172e-02 -4.13724976e-05 -1.99425973e-03],
#  max: [0.99871711 0.99542179 1.00190423 0.97946956],
#  mean: [0.44456744 0.39632158 0.21846847 0.4498564 ],
#  std: [0.34278209 0.22674763 0.29753782 0.22361584]
#
# Training time: 2.0335
# Train Fx MAE: 0.3450 ± 0.0974
# Train Fx MSE: 0.3574 ± 0.2285
# Train Fx R2: 0.9949 ± 0.0059
# Train Fy MAE: 0.3081 ± 0.1902
# Train Fy MSE: 0.3392 ± 0.4813
# Train Fy R2: 0.9907 ± 0.0046
# Train Fz MAE: 0.3856 ± 0.0964
# Train Fz MSE: 0.4577 ± 0.2117
# Train Fz R2: 0.9932 ± 0.0078
# Test Fx MAE: 0.7946 ± 0.2076
# Test Fx MSE: 1.3042 ± 0.6505
# Test Fx R2: 0.9786 ± 0.0245
# Test Fy MAE: 0.8114 ± 0.5863
# Test Fy MSE: 2.1939 ± 3.8007
# Test Fy R2: 0.9446 ± 0.0363
# Test Fz MAE: 0.8724 ± 0.2592
# Test Fz MSE: 1.6367 ± 0.8565
# Test Fz R2: 0.9643 ± 0.0583
#
#
# ../../../data/17022021/2
# Droping 0 data points by null features
# X: (17914, 4), Y: (17914, 24)
# Train -> X: (12540, 4), Y: (12540, 24)
# Test -> X: (5374, 4), Y: (5374, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43769595 0.37344622 0.21528003 0.35844264],
#  std: [0.34142328 0.2118653  0.29601244 0.23645877]
#
# Test ->
#  min: [ 7.85666286e-04  5.79289808e-02 -6.77822044e-05 -3.82091841e-03],
#  max: [0.99877058 1.00186153 1.01086568 0.97839806],
#  mean: [0.44721241 0.37565876 0.22270006 0.35142359],
#  std: [0.34301109 0.21348561 0.30290448 0.23627748]
#
# Training time: 2.0152
# Train Fx MAE: 0.3538 ± 0.1267
# Train Fx MSE: 0.3533 ± 0.2000
# Train Fx R2: 0.9980 ± 0.0020
# Train Fy MAE: 0.3731 ± 0.2251
# Train Fy MSE: 0.4839 ± 0.5100
# Train Fy R2: 0.9934 ± 0.0047
# Train Fz MAE: 0.4266 ± 0.1862
# Train Fz MSE: 0.6062 ± 0.4654
# Train Fz R2: 0.9963 ± 0.0031
# Test Fx MAE: 1.1441 ± 0.4342
# Test Fx MSE: 3.2645 ± 2.0822
# Test Fx R2: 0.9818 ± 0.0153
# Test Fy MAE: 1.0735 ± 0.6259
# Test Fy MSE: 3.7333 ± 3.8902
# Test Fy R2: 0.9308 ± 0.0556
# Test Fz MAE: 1.3842 ± 0.5908
# Test Fz MSE: 5.5119 ± 4.1740
# Test Fz R2: 0.9509 ± 0.0588
#
#
# ../../../data/17022021/3
# Droping 0 data points by null features
# X: (17960, 4), Y: (17960, 24)
# Train -> X: (12572, 4), Y: (12572, 24)
# Test -> X: (5388, 4), Y: (5388, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43603477 0.40188366 0.20944249 0.40680396],
#  std: [0.34010188 0.20269084 0.29114541 0.23585851]
#
# Test ->
#  min: [-6.52103093e-05  1.06968074e-01 -6.46151123e-05 -6.69320391e-03],
#  max: [1.00031632 0.99634038 1.00882913 1.00237989],
#  mean: [0.44499072 0.40113692 0.21630756 0.39540261],
#  std: [0.34275446 0.20456961 0.29858344 0.23230689]
#
# Training time: 2.1485
# Train Fx MAE: 0.2928 ± 0.1113
# Train Fx MSE: 0.3787 ± 0.4186
# Train Fx R2: 0.9970 ± 0.0012
# Train Fy MAE: 0.2496 ± 0.1656
# Train Fy MSE: 0.2762 ± 0.3924
# Train Fy R2: 0.9960 ± 0.0027
# Train Fz MAE: 0.2773 ± 0.1173
# Train Fz MSE: 0.3101 ± 0.2855
# Train Fz R2: 0.9967 ± 0.0030
# Test Fx MAE: 1.0696 ± 0.3519
# Test Fx MSE: 2.4022 ± 1.3984
# Test Fx R2: 0.9688 ± 0.0174
# Test Fy MAE: 0.8134 ± 0.5099
# Test Fy MSE: 2.0935 ± 2.9593
# Test Fy R2: 0.9650 ± 0.0190
# Test Fz MAE: 1.3371 ± 0.9272
# Test Fz MSE: 4.5155 ± 4.9058
# Test Fz R2: 0.9675 ± 0.0263
#
#
# ../../../data/17022021/4
# Droping 0 data points by null features
# X: (17884, 4), Y: (17884, 24)
# Train -> X: (12519, 4), Y: (12519, 24)
# Test -> X: (5365, 4), Y: (5365, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43826231 0.36814592 0.20842891 0.40532531],
#  std: [0.33924105 0.21347226 0.29209549 0.22120552]
#
# Test ->
#  min: [ 1.47142357e-03  6.19999323e-02 -5.39160945e-05 -4.11488783e-03],
#  max: [0.99943359 1.00043879 1.00158896 0.97472959],
#  mean: [0.44768742 0.37086428 0.21494153 0.40243141],
#  std: [0.34124934 0.21382734 0.29613212 0.22219522]
#
# Training time: 2.3368
# Train Fx MAE: 0.3397 ± 0.0954
# Train Fx MSE: 0.3903 ± 0.2499
# Train Fx R2: 0.9956 ± 0.0017
# Train Fy MAE: 0.2738 ± 0.1494
# Train Fy MSE: 0.2944 ± 0.3016
# Train Fy R2: 0.9948 ± 0.0039
# Train Fz MAE: 0.3235 ± 0.1054
# Train Fz MSE: 0.3214 ± 0.1832
# Train Fz R2: 0.9962 ± 0.0032
# Test Fx MAE: 5.7727 ± 2.0738
# Test Fx MSE: 87.6263 ± 48.4929
# Test Fx R2: -0.1571 ± 0.4340
# Test Fy MAE: 3.9211 ± 2.7962
# Test Fy MSE: 58.1713 ± 80.2254
# Test Fy R2: -1.0277 ± 3.5184
# Test Fz MAE: 6.4888 ± 2.8753
# Test Fz MSE: 165.6913 ± 204.8628
# Test Fz R2: -1.8100 ± 3.4008
#
#
# ../../../data/19022021/1
# Droping 0 data points by null features
# X: (17907, 4), Y: (17907, 24)
# Train -> X: (12535, 4), Y: (12535, 24)
# Test -> X: (5372, 4), Y: (5372, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43729711 0.33923612 0.21091736 0.46856447],
#  std: [0.33933627 0.21177887 0.29394099 0.21284523]
#
# Test ->
#  min: [ 8.95691340e-04 -8.08506234e-03 -5.05591776e-05 -4.89992748e-03],
#  max: [0.99997707 1.01272075 1.00677817 0.97759504],
#  mean: [0.44678444 0.34744487 0.21895254 0.45068456],
#  std: [0.34135106 0.2175253  0.30090463 0.21392371]
#
# Training time: 2.5596
# Train Fx MAE: 0.3322 ± 0.1119
# Train Fx MSE: 0.4067 ± 0.2433
# Train Fx R2: 0.9918 ± 0.0020
# Train Fy MAE: 0.3989 ± 0.2140
# Train Fy MSE: 0.6067 ± 0.5276
# Train Fy R2: 0.9903 ± 0.0035
# Train Fz MAE: 0.3588 ± 0.1202
# Train Fz MSE: 0.4096 ± 0.2386
# Train Fz R2: 0.9944 ± 0.0021
# Test Fx MAE: 0.8379 ± 0.2180
# Test Fx MSE: 1.4475 ± 0.7099
# Test Fx R2: 0.9564 ± 0.0198
# Test Fy MAE: 1.0060 ± 0.5304
# Test Fy MSE: 2.6940 ± 2.4872
# Test Fy R2: 0.9545 ± 0.0251
# Test Fz MAE: 0.8890 ± 0.2855
# Test Fz MSE: 1.7915 ± 1.0008
# Test Fz R2: 0.9692 ± 0.0183
#
#
# ../../../data/19022021/10
# Droping 0 data points by null features
# X: (17947, 4), Y: (17947, 24)
# Train -> X: (12563, 4), Y: (12563, 24)
# Test -> X: (5384, 4), Y: (5384, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43737324 0.3648973  0.22358517 0.33043975],
#  std: [0.34079437 0.20847359 0.30229103 0.24112484]
#
# Test ->
#  min: [-3.34614778e-04  1.24955474e-02 -6.41855008e-05 -4.04007534e-03],
#  max: [1.0001797  1.01057632 1.00088644 0.98526518],
#  mean: [0.44649937 0.37021641 0.23076054 0.32488186],
#  std: [0.34325781 0.21299449 0.30954118 0.24015413]
#
# Training time: 2.2134
# Train Fx MAE: 0.3405 ± 0.1576
# Train Fx MSE: 0.3521 ± 0.3214
# Train Fx R2: 0.9979 ± 0.0025
# Train Fy MAE: 0.4628 ± 0.3459
# Train Fy MSE: 0.8464 ± 1.0112
# Train Fy R2: 0.9935 ± 0.0037
# Train Fz MAE: 0.4365 ± 0.2654
# Train Fz MSE: 0.7265 ± 0.7853
# Train Fz R2: 0.9968 ± 0.0031
# Test Fx MAE: 1.2931 ± 0.6666
# Test Fx MSE: 4.4948 ± 4.7970
# Test Fx R2: 0.9683 ± 0.0447
# Test Fy MAE: 1.8377 ± 1.3976
# Test Fy MSE: 10.4421 ± 12.4827
# Test Fy R2: 0.9121 ± 0.0694
# Test Fz MAE: 1.8115 ± 1.2672
# Test Fz MSE: 9.6481 ± 11.4263
# Test Fz R2: 0.9627 ± 0.0398
#
#
# ../../../data/19022021/11
# Droping 0 data points by null features
# X: (17935, 4), Y: (17935, 24)
# Train -> X: (12555, 4), Y: (12555, 24)
# Test -> X: (5380, 4), Y: (5380, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43783514 0.36235956 0.22280056 0.32997943],
#  std: [0.34053319 0.21172534 0.30332742 0.23906259]
#
# Test ->
#  min: [-7.58384990e-04  3.71039354e-03 -5.94337411e-05  1.80232797e-03],
#  max: [0.99957267 0.99083777 1.00378275 0.99699218],
#  mean: [0.44662772 0.3630524  0.22920659 0.33033851],
#  std: [0.34256265 0.21439008 0.3083529  0.24077442]
#
# Training time: 2.1054
# Train Fx MAE: 0.3074 ± 0.1503
# Train Fx MSE: 0.2550 ± 0.2194
# Train Fx R2: 0.9976 ± 0.0036
# Train Fy MAE: 0.4041 ± 0.3199
# Train Fy MSE: 0.6325 ± 0.7662
# Train Fy R2: 0.9951 ± 0.0037
# Train Fz MAE: 0.3568 ± 0.2126
# Train Fz MSE: 0.4248 ± 0.3935
# Train Fz R2: 0.9978 ± 0.0023
# Test Fx MAE: 0.9112 ± 0.4426
# Test Fx MSE: 2.0937 ± 1.9312
# Test Fx R2: 0.9768 ± 0.0401
# Test Fy MAE: 1.1888 ± 0.9534
# Test Fy MSE: 5.2315 ± 6.7922
# Test Fy R2: 0.9593 ± 0.0343
# Test Fz MAE: 1.0495 ± 0.6162
# Test Fz MSE: 3.5114 ± 3.3010
# Test Fz R2: 0.9813 ± 0.0201
#
#
# ../../../data/19022021/12
# Droping 0 data points by null features
# X: (17958, 4), Y: (17958, 24)
# Train -> X: (12571, 4), Y: (12571, 24)
# Test -> X: (5387, 4), Y: (5387, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43702458 0.35968444 0.21148035 0.37016374],
#  std: [0.34004719 0.21005065 0.29237462 0.22562999]
#
# Test ->
#  min: [ 6.05265082e-04  2.86264479e-02 -6.00752807e-05 -4.96825340e-03],
#  max: [1.00016406 0.98884249 1.00444351 0.98654853],
#  mean: [0.44633194 0.3616975  0.21787179 0.36514983],
#  std: [0.34277591 0.21331395 0.29867344 0.22365695]
#
# Training time: 2.0135
# Train Fx MAE: 0.3227 ± 0.1394
# Train Fx MSE: 0.2920 ± 0.2390
# Train Fx R2: 0.9973 ± 0.0023
# Train Fy MAE: 0.3638 ± 0.2377
# Train Fy MSE: 0.4395 ± 0.5854
# Train Fy R2: 0.9957 ± 0.0017
# Train Fz MAE: 0.3825 ± 0.1877
# Train Fz MSE: 0.5025 ± 0.3777
# Train Fz R2: 0.9965 ± 0.0034
# Test Fx MAE: 1.0417 ± 0.4684
# Test Fx MSE: 2.6168 ± 2.1329
# Test Fx R2: 0.9678 ± 0.0338
# Test Fy MAE: 1.3143 ± 0.9155
# Test Fy MSE: 5.2869 ± 7.0883
# Test Fy R2: 0.9486 ± 0.0271
# Test Fz MAE: 1.2644 ± 0.7084
# Test Fz MSE: 4.5282 ± 4.2361
# Test Fz R2: 0.9715 ± 0.0267
#
#
# ../../../data/19022021/13
# Droping 0 data points by null features
# X: (11912, 4), Y: (11912, 24)
# Train -> X: (8339, 4), Y: (8339, 24)
# Test -> X: (3573, 4), Y: (3573, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43661445 0.37465109 0.21565407 0.33623894],
#  std: [0.33968746 0.21743992 0.29662245 0.22762957]
#
# Test ->
#  min: [-1.99164980e-04  2.29826517e-05  4.22531100e-06 -5.65361994e-01],
#  max: [1.00107919 1.02787875 1.00296365 1.05816951],
#  mean: [0.45511382 0.41250034 0.24848973 0.22523294],
#  std: [0.34602797 0.2267736  0.30519391 0.3588297 ]
#
# Training time: 1.2297
# Train Fx MAE: 0.3057 ± 0.1086
# Train Fx MSE: 0.2450 ± 0.1468
# Train Fx R2: 0.9982 ± 0.0010
# Train Fy MAE: 0.3505 ± 0.2528
# Train Fy MSE: 0.4646 ± 0.6881
# Train Fy R2: 0.9968 ± 0.0023
# Train Fz MAE: 0.4310 ± 0.2061
# Train Fz MSE: 0.6394 ± 0.5534
# Train Fz R2: 0.9967 ± 0.0040
# Test Fx MAE: 8.6220 ± 4.2890
# Test Fx MSE: 382.3945 ± 340.5167
# Test Fx R2: 0.2426 ± 0.2694
# Test Fy MAE: 5.1574 ± 3.3723
# Test Fy MSE: 161.0450 ± 218.9593
# Test Fy R2: 0.4127 ± 0.2371
# Test Fz MAE: 10.2180 ± 4.4360
# Test Fz MSE: 552.6687 ± 451.5558
# Test Fz R2: 0.3577 ± 0.4027
#
#
# ../../../data/19022021/14
# Droping 0 data points by null features
# X: (17930, 4), Y: (17930, 24)
# Train -> X: (12551, 4), Y: (12551, 24)
# Test -> X: (5379, 4), Y: (5379, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43803037 0.35220117 0.20706634 0.39217096],
#  std: [0.34044773 0.20746859 0.29044472 0.20989675]
#
# Test ->
#  min: [-2.42508165e-05 -1.33834045e-02 -5.99302329e-05  6.40040711e-03],
#  max: [1.00021217 0.99213101 1.00039223 0.94533081],
#  mean: [0.44735616 0.3496052  0.21356964 0.38596151],
#  std: [0.34306131 0.21200052 0.29604981 0.20429107]
#
# Training time: 2.1537
# Train Fx MAE: 0.3794 ± 0.1138
# Train Fx MSE: 0.3865 ± 0.1815
# Train Fx R2: 0.9975 ± 0.0012
# Train Fy MAE: 0.5366 ± 0.2951
# Train Fy MSE: 0.9795 ± 0.8409
# Train Fy R2: 0.9949 ± 0.0026
# Train Fz MAE: 0.4492 ± 0.1818
# Train Fz MSE: 0.5724 ± 0.3105
# Train Fz R2: 0.9971 ± 0.0028
# Test Fx MAE: 1.6681 ± 0.5599
# Test Fx MSE: 7.2225 ± 4.1601
# Test Fx R2: 0.9395 ± 0.0401
# Test Fy MAE: 2.2314 ± 1.3014
# Test Fy MSE: 17.5038 ± 17.4877
# Test Fy R2: 0.8620 ± 0.0866
# Test Fz MAE: 2.2442 ± 1.0054
# Test Fz MSE: 14.3630 ± 10.3203
# Test Fz R2: 0.9167 ± 0.0706
#
#
# ../../../data/19022021/15
# Droping 0 data points by null features
# X: (17972, 4), Y: (17972, 24)
# Train -> X: (12581, 4), Y: (12581, 24)
# Test -> X: (5391, 4), Y: (5391, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43461061 0.36481395 0.21111677 0.38934865],
#  std: [0.33861839 0.21853505 0.29468275 0.20675883]
#
# Test ->
#  min: [-2.29155793e-04  6.87292620e-03 -1.19799507e-05  2.27866185e-04],
#  max: [0.9999844  0.99693836 0.99919809 0.99604465],
#  mean: [0.44712263 0.36507033 0.21661794 0.38653474],
#  std: [0.34028069 0.21835561 0.29949158 0.20692037]
#
# Training time: 2.0819
# Train Fx MAE: 0.3235 ± 0.1096
# Train Fx MSE: 0.2550 ± 0.1268
# Train Fx R2: 0.9981 ± 0.0010
# Train Fy MAE: 0.3984 ± 0.2334
# Train Fy MSE: 0.4752 ± 0.4075
# Train Fy R2: 0.9970 ± 0.0011
# Train Fz MAE: 0.3362 ± 0.1509
# Train Fz MSE: 0.3131 ± 0.1990
# Train Fz R2: 0.9983 ± 0.0012
# Test Fx MAE: 0.9358 ± 0.3212
# Test Fx MSE: 2.0089 ± 1.0289
# Test Fx R2: 0.9856 ± 0.0069
# Test Fy MAE: 1.1609 ± 0.6585
# Test Fy MSE: 3.6146 ± 2.9598
# Test Fy R2: 0.9753 ± 0.0096
# Test Fz MAE: 0.9817 ± 0.4510
# Test Fz MSE: 2.4745 ± 1.6771
# Test Fz R2: 0.9858 ± 0.0110
#
#
# ../../../data/19022021/16
# Droping 0 data points by null features
# X: (16954, 4), Y: (16954, 24)
# Train -> X: (11868, 4), Y: (11868, 24)
# Test -> X: (5086, 4), Y: (5086, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43755575 0.36997558 0.21368886 0.42339329],
#  std: [0.33865655 0.21931527 0.29597491 0.2054365 ]
#
# Test ->
#  min: [2.44206178e-04 1.52553122e-02 6.39439569e-06 4.35854706e-03],
#  max: [1.00095628 0.99839149 1.0014471  0.96488845],
#  mean: [0.44635966 0.37749024 0.21467068 0.41165994],
#  std: [0.34125539 0.22077216 0.29720632 0.19999101]
#
# Training time: 2.1274
# Train Fx MAE: 0.4860 ± 0.1384
# Train Fx MSE: 0.7249 ± 0.3884
# Train Fx R2: 0.9927 ± 0.0025
# Train Fy MAE: 0.4442 ± 0.2385
# Train Fy MSE: 0.6820 ± 0.5859
# Train Fy R2: 0.9927 ± 0.0046
# Train Fz MAE: 0.6061 ± 0.2418
# Train Fz MSE: 1.1409 ± 0.6233
# Train Fz R2: 0.9910 ± 0.0077
# Test Fx MAE: 1.2170 ± 0.3850
# Test Fx MSE: 4.8345 ± 3.3067
# Test Fx R2: 0.9251 ± 0.0497
# Test Fy MAE: 1.0648 ± 0.6237
# Test Fy MSE: 3.7594 ± 4.0092
# Test Fy R2: 0.9580 ± 0.0190
# Test Fz MAE: 1.5643 ± 0.5959
# Test Fz MSE: 8.0793 ± 4.9633
# Test Fz R2: 0.8046 ± 0.2749
#
#
# ../../../data/19022021/17
# Droping 0 data points by null features
# X: (17966, 4), Y: (17966, 24)
# Train -> X: (12577, 4), Y: (12577, 24)
# Test -> X: (5389, 4), Y: (5389, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43730745 0.39474927 0.20751619 0.41356832],
#  std: [0.33870057 0.20566361 0.29148381 0.205948  ]
#
# Test ->
#  min: [ 5.62586173e-03  1.44323066e-02 -5.91896087e-05 -5.29139226e-04],
#  max: [0.9997658  1.00031987 1.00353755 0.99165134],
#  mean: [0.44586693 0.39878239 0.21286438 0.41069835],
#  std: [0.34027811 0.20688937 0.29566548 0.20805424]
#
# Training time: 2.1474
# Train Fx MAE: 0.3661 ± 0.1325
# Train Fx MSE: 0.3106 ± 0.1914
# Train Fx R2: 0.9967 ± 0.0019
# Train Fy MAE: 0.3708 ± 0.2358
# Train Fy MSE: 0.4370 ± 0.4699
# Train Fy R2: 0.9973 ± 0.0012
# Train Fz MAE: 0.4437 ± 0.2049
# Train Fz MSE: 0.5082 ± 0.3750
# Train Fz R2: 0.9963 ± 0.0045
# Test Fx MAE: 2.2075 ± 0.9005
# Test Fx MSE: 13.2218 ± 10.6663
# Test Fx R2: 0.8454 ± 0.1116
# Test Fy MAE: 2.0117 ± 1.1669
# Test Fy MSE: 12.5686 ± 13.1326
# Test Fy R2: 0.8943 ± 0.0721
# Test Fz MAE: 3.5755 ± 1.8365
# Test Fz MSE: 37.6536 ± 35.3023
# Test Fz R2: 0.7656 ± 0.2634
#
#
# ../../../data/19022021/18
# Droping 0 data points by null features
# X: (17944, 4), Y: (17944, 24)
# Train -> X: (12561, 4), Y: (12561, 24)
# Test -> X: (5383, 4), Y: (5383, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43746689 0.37643317 0.2061972  0.3858043 ],
#  std: [0.34028301 0.19696889 0.29038903 0.20559578]
#
# Test ->
#  min: [ 8.97950694e-04  2.14011370e-02 -5.49983376e-05  1.14218959e-02],
#  max: [1.00024233 1.00084946 1.00210904 0.93456873],
#  mean: [0.44644125 0.38949419 0.21223336 0.37353007],
#  std: [0.34230801 0.20096842 0.29516186 0.20050656]
#
# Training time: 2.1419
# Train Fx MAE: 0.4658 ± 0.1389
# Train Fx MSE: 0.5670 ± 0.2747
# Train Fx R2: 0.9957 ± 0.0014
# Train Fy MAE: 0.5428 ± 0.3258
# Train Fy MSE: 0.8834 ± 0.9116
# Train Fy R2: 0.9942 ± 0.0028
# Train Fz MAE: 0.5427 ± 0.2280
# Train Fz MSE: 0.8831 ± 0.5907
# Train Fz R2: 0.9949 ± 0.0038
# Test Fx MAE: 2.8706 ± 0.8604
# Test Fx MSE: 23.3748 ± 14.6690
# Test Fx R2: 0.8029 ± 0.1141
# Test Fy MAE: 3.0706 ± 1.7052
# Test Fy MSE: 30.6613 ± 30.7287
# Test Fy R2: 0.6307 ± 0.3537
# Test Fz MAE: 3.5745 ± 1.4325
# Test Fz MSE: 40.1885 ± 28.7517
# Test Fz R2: 0.5039 ± 0.7120
#
#
# ../../../data/19022021/2
# Droping 0 data points by null features
# X: (17912, 4), Y: (17912, 24)
# Train -> X: (12539, 4), Y: (12539, 24)
# Test -> X: (5373, 4), Y: (5373, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43650672 0.35533409 0.21004485 0.47277778],
#  std: [0.33935792 0.21104431 0.29449509 0.21406308]
#
# Test ->
#  min: [ 6.46610467e-06  6.85737328e-03 -6.36013469e-05  1.38476209e-03],
#  max: [1.0000457  1.00359984 1.00109995 0.99426701],
#  mean: [0.44610293 0.35974321 0.21609904 0.46762341],
#  std: [0.34130495 0.21416564 0.29870744 0.2150393 ]
#
# Training time: 2.4801
# Train Fx MAE: 0.2566 ± 0.0949
# Train Fx MSE: 0.1637 ± 0.1128
# Train Fx R2: 0.9956 ± 0.0016
# Train Fy MAE: 0.2989 ± 0.1761
# Train Fy MSE: 0.2645 ± 0.3523
# Train Fy R2: 0.9961 ± 0.0026
# Train Fz MAE: 0.2652 ± 0.1127
# Train Fz MSE: 0.1736 ± 0.1492
# Train Fz R2: 0.9970 ± 0.0027
# Test Fx MAE: 0.8725 ± 0.2941
# Test Fx MSE: 1.7589 ± 1.1858
# Test Fx R2: 0.9523 ± 0.0169
# Test Fy MAE: 1.0449 ± 0.5538
# Test Fy MSE: 3.0302 ± 3.7657
# Test Fy R2: 0.9563 ± 0.0242
# Test Fz MAE: 1.0083 ± 0.3446
# Test Fz MSE: 2.3041 ± 1.6351
# Test Fz R2: 0.9594 ± 0.0340
#
#
# ../../../data/19022021/3
# Droping 0 data points by null features
# X: (17953, 4), Y: (17953, 24)
# Train -> X: (12568, 4), Y: (12568, 24)
# Test -> X: (5385, 4), Y: (5385, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43552937 0.34994021 0.20863061 0.46740191],
#  std: [0.33842097 0.20921505 0.29338886 0.20925643]
#
# Test ->
#  min: [-7.07665693e-05  1.63265177e-02 -6.46486291e-05  2.81699519e-03],
#  max: [0.9992555  0.99340655 1.00094196 0.98030417],
#  mean: [0.44434586 0.3557171  0.21339476 0.46176752],
#  std: [0.34085575 0.21482114 0.29676329 0.21202684]
#
# Training time: 2.3893
# Train Fx MAE: 0.2773 ± 0.1010
# Train Fx MSE: 0.1902 ± 0.1244
# Train Fx R2: 0.9951 ± 0.0015
# Train Fy MAE: 0.3282 ± 0.1647
# Train Fy MSE: 0.3118 ± 0.3462
# Train Fy R2: 0.9949 ± 0.0030
# Train Fz MAE: 0.3188 ± 0.1479
# Train Fz MSE: 0.2765 ± 0.2459
# Train Fz R2: 0.9957 ± 0.0046
# Test Fx MAE: 1.7461 ± 0.8159
# Test Fx MSE: 8.4713 ± 7.0952
# Test Fx R2: 0.7775 ± 0.1568
# Test Fy MAE: 2.2897 ± 0.9591
# Test Fy MSE: 17.8297 ± 16.8917
# Test Fy R2: 0.0197 ± 1.4761
# Test Fz MAE: 2.3871 ± 1.5538
# Test Fz MSE: 18.1400 ± 24.9133
# Test Fz R2: 0.6329 ± 0.6600
#
#
# ../../../data/19022021/4
# Droping 0 data points by null features
# X: (17919, 4), Y: (17919, 24)
# Train -> X: (12544, 4), Y: (12544, 24)
# Test -> X: (5375, 4), Y: (5375, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43643345 0.34096601 0.20814692 0.47446813],
#  std: [0.33842428 0.21440183 0.29323938 0.21067649]
#
# Test ->
#  min: [ 3.55705965e-04 -6.50747772e-04 -6.30912387e-05  2.36793486e-03],
#  max: [0.99986276 0.9999745  0.99892308 0.98131892],
#  mean: [0.44597491 0.34490045 0.21395334 0.47099897],
#  std: [0.34019356 0.21750321 0.2968885  0.20904673]
#
# Training time: 2.0793
# Train Fx MAE: 0.2914 ± 0.1071
# Train Fx MSE: 0.2468 ± 0.1759
# Train Fx R2: 0.9940 ± 0.0025
# Train Fy MAE: 0.3221 ± 0.1800
# Train Fy MSE: 0.3213 ± 0.4165
# Train Fy R2: 0.9939 ± 0.0039
# Train Fz MAE: 0.2758 ± 0.1070
# Train Fz MSE: 0.1928 ± 0.1454
# Train Fz R2: 0.9969 ± 0.0026
# Test Fx MAE: 1.4366 ± 0.6722
# Test Fx MSE: 9.7427 ± 9.4526
# Test Fx R2: 0.7802 ± 0.1481
# Test Fy MAE: 1.3514 ± 0.6664
# Test Fy MSE: 5.6515 ± 5.0473
# Test Fy R2: 0.8640 ± 0.0952
# Test Fz MAE: 1.1955 ± 0.5573
# Test Fz MSE: 4.7673 ± 5.6054
# Test Fz R2: 0.9450 ± 0.0361
#
#
# ../../../data/19022021/5
# Droping 0 data points by null features
# X: (17946, 4), Y: (17946, 24)
# Train -> X: (12563, 4), Y: (12563, 24)
# Test -> X: (5383, 4), Y: (5383, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.4367418  0.34389254 0.21073796 0.47323383],
#  std: [0.33771102 0.2247175  0.2949264  0.20446883]
#
# Test ->
#  min: [ 9.64740088e-04  6.63532859e-03 -1.19058975e-05 -6.73621626e-03],
#  max: [1.00007651 1.00384888 1.00001167 0.99605866],
#  mean: [0.44987154 0.34687051 0.217934   0.47504978],
#  std: [0.33853912 0.22747947 0.29990352 0.20675354]
#
# Training time: 2.1223
# Train Fx MAE: 0.2703 ± 0.0975
# Train Fx MSE: 0.1893 ± 0.1303
# Train Fx R2: 0.9955 ± 0.0016
# Train Fy MAE: 0.3149 ± 0.1823
# Train Fy MSE: 0.2895 ± 0.3587
# Train Fy R2: 0.9943 ± 0.0044
# Train Fz MAE: 0.2932 ± 0.1143
# Train Fz MSE: 0.2040 ± 0.1505
# Train Fz R2: 0.9969 ± 0.0029
# Test Fx MAE: 1.2615 ± 0.5088
# Test Fx MSE: 5.0095 ± 4.3356
# Test Fx R2: 0.8914 ± 0.0501
# Test Fy MAE: 1.2959 ± 0.8004
# Test Fy MSE: 5.7023 ± 8.0709
# Test Fy R2: 0.9076 ± 0.0475
# Test Fz MAE: 1.4482 ± 0.5984
# Test Fz MSE: 5.4204 ± 4.8928
# Test Fz R2: 0.9376 ± 0.0470
#
#
# ../../../data/19022021/6
# Droping 0 data points by null features
# X: (17969, 4), Y: (17969, 24)
# Train -> X: (12579, 4), Y: (12579, 24)
# Test -> X: (5390, 4), Y: (5390, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43625291 0.34070696 0.21133886 0.47774315],
#  std: [0.33784212 0.22189534 0.29464816 0.2030014 ]
#
# Test ->
#  min: [-2.48436053e-04  1.24641522e-03 -1.20792480e-05 -5.85534679e-04],
#  max: [0.99996132 0.99897882 1.00137481 0.98600258],
#  mean: [0.4488843  0.3422222  0.2169886  0.47375423],
#  std: [0.33914353 0.22491251 0.29979304 0.2043346 ]
#
# Training time: 2.0451
# Train Fx MAE: 0.2882 ± 0.0931
# Train Fx MSE: 0.1999 ± 0.1212
# Train Fx R2: 0.9953 ± 0.0019
# Train Fy MAE: 0.3599 ± 0.2078
# Train Fy MSE: 0.3795 ± 0.4645
# Train Fy R2: 0.9944 ± 0.0032
# Train Fz MAE: 0.3277 ± 0.1283
# Train Fz MSE: 0.2784 ± 0.2130
# Train Fz R2: 0.9966 ± 0.0036
# Test Fx MAE: 1.0446 ± 0.3803
# Test Fx MSE: 2.6321 ± 2.1878
# Test Fx R2: 0.9349 ± 0.0290
# Test Fy MAE: 1.2165 ± 0.7309
# Test Fy MSE: 4.2397 ± 5.3319
# Test Fy R2: 0.9157 ± 0.0838
# Test Fz MAE: 1.1901 ± 0.3318
# Test Fz MSE: 3.2058 ± 1.7470
# Test Fz R2: 0.9518 ± 0.0456
#
#
# ../../../data/19022021/7
# Droping 0 data points by null features
# X: (17938, 4), Y: (17938, 24)
# Train -> X: (12557, 4), Y: (12557, 24)
# Test -> X: (5381, 4), Y: (5381, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43644364 0.37717442 0.20709456 0.47458898],
#  std: [0.33766896 0.21038901 0.29221891 0.19670504]
#
# Test ->
#  min: [ 1.85931351e-03  5.99220169e-02 -6.11135467e-05 -9.63358234e-03],
#  max: [0.99958533 0.99768448 0.99851161 0.95753778],
#  mean: [0.44607845 0.38695009 0.21266698 0.46004455],
#  std: [0.33964811 0.21435889 0.2961005  0.19821781]
#
# Training time: 2.4304
# Train Fx MAE: 0.3396 ± 0.1240
# Train Fx MSE: 0.3498 ± 0.2698
# Train Fx R2: 0.9909 ± 0.0035
# Train Fy MAE: 0.3140 ± 0.1452
# Train Fy MSE: 0.3639 ± 0.3342
# Train Fy R2: 0.9921 ± 0.0033
# Train Fz MAE: 0.3981 ± 0.1574
# Train Fz MSE: 0.5396 ± 0.3787
# Train Fz R2: 0.9933 ± 0.0041
# Test Fx MAE: 1.9803 ± 1.0810
# Test Fx MSE: 9.6600 ± 9.5199
# Test Fx R2: 0.6753 ± 0.2028
# Test Fy MAE: 1.3866 ± 0.5667
# Test Fy MSE: 4.3906 ± 2.8674
# Test Fy R2: 0.7978 ± 0.2697
# Test Fz MAE: 2.9905 ± 2.3632
# Test Fz MSE: 24.2333 ± 31.3816
# Test Fz R2: 0.6692 ± 0.2859
#
#
# ../../../data/19022021/8
# Droping 0 data points by null features
# X: (17982, 4), Y: (17982, 24)
# Train -> X: (12588, 4), Y: (12588, 24)
# Test -> X: (5394, 4), Y: (5394, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43627202 0.37303495 0.21069095 0.47998502],
#  std: [0.33811065 0.22335446 0.29463649 0.20794454]
#
# Test ->
#  min: [ 2.37937191e-05  4.06094701e-02 -1.05722792e-05  5.14156212e-04],
#  max: [0.99963231 1.00137627 1.00189692 0.97834668],
#  mean: [0.44871362 0.37640046 0.21627032 0.47360595],
#  std: [0.34120713 0.22314761 0.29954942 0.20829014]
#
# Training time: 2.6204
# Train Fx MAE: 0.2710 ± 0.0903
# Train Fx MSE: 0.1791 ± 0.1074
# Train Fx R2: 0.9960 ± 0.0017
# Train Fy MAE: 0.2874 ± 0.1531
# Train Fy MSE: 0.2252 ± 0.1948
# Train Fy R2: 0.9967 ± 0.0019
# Train Fz MAE: 0.2837 ± 0.1132
# Train Fz MSE: 0.2216 ± 0.1630
# Train Fz R2: 0.9980 ± 0.0008
# Test Fx MAE: 1.2615 ± 0.5232
# Test Fx MSE: 3.9667 ± 3.0255
# Test Fx R2: 0.9069 ± 0.0449
# Test Fy MAE: 1.2898 ± 0.7138
# Test Fy MSE: 5.0545 ± 4.5461
# Test Fy R2: 0.9178 ± 0.0504
# Test Fz MAE: 1.3778 ± 0.5866
# Test Fz MSE: 6.0658 ± 4.0371
# Test Fz R2: 0.9053 ± 0.1041
#
#
# ../../../data/19022021/9
# Droping 0 data points by null features
# X: (17907, 4), Y: (17907, 24)
# Train -> X: (12535, 4), Y: (12535, 24)
# Test -> X: (5372, 4), Y: (5372, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43758581 0.37274695 0.22083258 0.32332693],
#  std: [0.33982244 0.21376032 0.30141493 0.2225634 ]
#
# Test ->
#  min: [ 1.68310967e-04  1.16970627e-02 -1.30470292e-05 -1.09330160e-02],
#  max: [1.0002179  0.98991126 1.00108426 0.93654227],
#  mean: [0.45027883 0.37011159 0.23018146 0.31014379],
#  std: [0.34157082 0.21737134 0.30764325 0.21450279]
#
# Training time: 2.2723
# Train Fx MAE: 0.3710 ± 0.1348
# Train Fx MSE: 0.4346 ± 0.2164
# Train Fx R2: 0.9971 ± 0.0026
# Train Fy MAE: 0.4085 ± 0.2722
# Train Fy MSE: 0.6899 ± 0.6920
# Train Fy R2: 0.9944 ± 0.0030
# Train Fz MAE: 0.4156 ± 0.2288
# Train Fz MSE: 0.6738 ± 0.5751
# Train Fz R2: 0.9968 ± 0.0025
# Test Fx MAE: 1.0798 ± 0.4155
# Test Fx MSE: 3.4305 ± 1.9166
# Test Fx R2: 0.9761 ± 0.0234
# Test Fy MAE: 1.2797 ± 0.8123
# Test Fy MSE: 6.2925 ± 6.2354
# Test Fy R2: 0.9302 ± 0.0444
# Test Fz MAE: 1.2690 ± 0.6764
# Test Fz MSE: 5.7749 ± 4.6888
# Test Fz R2: 0.9616 ± 0.0375
#
#
# ../../../data/22022021/1
# Droping 0 data points by null features
# X: (17932, 4), Y: (17932, 24)
# Train -> X: (12553, 4), Y: (12553, 24)
# Test -> X: (5379, 4), Y: (5379, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43647697 0.33934804 0.20810464 0.41761182],
#  std: [0.33969375 0.21624789 0.29144894 0.22453094]
#
# Test ->
#  min: [-4.82094886e-04  1.03967619e-02 -5.26546735e-05 -1.57083783e-03],
#  max: [0.99546851 1.00686013 1.00044754 0.98685302],
#  mean: [0.44557152 0.34961423 0.21403036 0.41348134],
#  std: [0.34156793 0.22180868 0.29566116 0.22970689]
#
# Training time: 2.4994
# Train Fx MAE: 0.4820 ± 0.1574
# Train Fx MSE: 0.5147 ± 0.2934
# Train Fx R2: 0.9938 ± 0.0040
# Train Fy MAE: 0.5698 ± 0.3195
# Train Fy MSE: 0.8722 ± 0.9677
# Train Fy R2: 0.9936 ± 0.0036
# Train Fz MAE: 0.6796 ± 0.2914
# Train Fz MSE: 1.0622 ± 0.7656
# Train Fz R2: 0.9936 ± 0.0068
# Test Fx MAE: 2.1152 ± 0.8740
# Test Fx MSE: 10.6002 ± 9.1727
# Test Fx R2: 0.8712 ± 0.0884
# Test Fy MAE: 2.4414 ± 1.3839
# Test Fy MSE: 17.1392 ± 22.6281
# Test Fy R2: 0.8609 ± 0.0949
# Test Fz MAE: 3.5581 ± 1.8823
# Test Fz MSE: 30.6992 ± 26.9437
# Test Fz R2: 0.7601 ± 0.3244
#
#
# ../../../data/22022021/10
# Droping 0 data points by null features
# X: (17972, 4), Y: (17972, 24)
# Train -> X: (12581, 4), Y: (12581, 24)
# Test -> X: (5391, 4), Y: (5391, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43730773 0.35582058 0.20769973 0.3530834 ],
#  std: [0.34025162 0.21643487 0.28582926 0.2146646 ]
#
# Test ->
#  min: [-1.21312180e-03  2.70581141e-02 -5.50151754e-05  1.40455958e-02],
#  max: [1.00099948 0.98078688 1.01604354 0.90096043],
#  mean: [0.44580334 0.36271343 0.21857341 0.33168974],
#  std: [0.34330663 0.2110566  0.30170897 0.19207666]
#
# Training time: 2.5906
# Train Fx MAE: 0.3667 ± 0.1017
# Train Fx MSE: 0.3907 ± 0.1611
# Train Fx R2: 0.9978 ± 0.0011
# Train Fy MAE: 0.3283 ± 0.1354
# Train Fy MSE: 0.3666 ± 0.2425
# Train Fy R2: 0.9952 ± 0.0034
# Train Fz MAE: 0.5068 ± 0.2236
# Train Fz MSE: 0.8954 ± 0.6987
# Train Fz R2: 0.9965 ± 0.0026
# Test Fx MAE: 3.4047 ± 1.0230
# Test Fx MSE: 39.0477 ± 28.9852
# Test Fx R2: 0.5752 ± 0.2563
# Test Fy MAE: 3.6070 ± 1.7836
# Test Fy MSE: 75.7637 ± 110.0186
# Test Fy R2: -1.4440 ± 3.1411
# Test Fz MAE: 5.2624 ± 2.6140
# Test Fz MSE: 105.2540 ± 102.9061
# Test Fz R2: -0.9804 ± 2.9731
#
#
# ../../../data/22022021/11
# Droping 0 data points by null features
# X: (17904, 4), Y: (17904, 24)
# Train -> X: (12533, 4), Y: (12533, 24)
# Test -> X: (5371, 4), Y: (5371, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43911544 0.35011181 0.22331762 0.3623883 ],
#  std: [0.34023654 0.21534039 0.30321246 0.23898686]
#
# Test ->
#  min: [ 3.55573080e-04  5.95888112e-03 -6.70371010e-05 -2.58163207e-03],
#  max: [0.99984804 0.99543507 1.00607877 0.9906452 ],
#  mean: [0.44854755 0.35107716 0.2308474  0.35460558],
#  std: [0.34212703 0.22062455 0.31005184 0.23914129]
#
# Training time: 2.5644
# Train Fx MAE: 0.2637 ± 0.0822
# Train Fx MSE: 0.1832 ± 0.1144
# Train Fx R2: 0.9990 ± 0.0008
# Train Fy MAE: 0.3153 ± 0.1831
# Train Fy MSE: 0.3568 ± 0.4067
# Train Fy R2: 0.9957 ± 0.0043
# Train Fz MAE: 0.3746 ± 0.1914
# Train Fz MSE: 0.5045 ± 0.4388
# Train Fz R2: 0.9986 ± 0.0010
# Test Fx MAE: 0.9222 ± 0.4370
# Test Fx MSE: 1.8807 ± 1.4938
# Test Fx R2: 0.9901 ± 0.0088
# Test Fy MAE: 0.9612 ± 0.5295
# Test Fy MSE: 3.4421 ± 3.9684
# Test Fy R2: 0.9596 ± 0.0422
# Test Fz MAE: 1.2319 ± 0.6290
# Test Fz MSE: 4.6459 ± 4.2323
# Test Fz R2: 0.9836 ± 0.0122
#
#
# ../../../data/22022021/12
# Droping 0 data points by null features
# X: (17911, 4), Y: (17911, 24)
# Train -> X: (12538, 4), Y: (12538, 24)
# Test -> X: (5373, 4), Y: (5373, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43806789 0.37983125 0.21428913 0.37030079],
#  std: [0.34038443 0.20688939 0.29313301 0.23184472]
#
# Test ->
#  min: [ 2.97203141e-05  5.87926660e-02 -6.29463606e-05  4.78509619e-03],
#  max: [1.00027792 0.99722386 1.00621302 0.9900818 ],
#  mean: [0.44757728 0.37948524 0.22348275 0.36169739],
#  std: [0.34257214 0.20902937 0.30366383 0.22666995]
#
# Training time: 2.1622
# Train Fx MAE: 0.3095 ± 0.1240
# Train Fx MSE: 0.3657 ± 0.2684
# Train Fx R2: 0.9970 ± 0.0026
# Train Fy MAE: 0.3640 ± 0.2246
# Train Fy MSE: 0.6546 ± 0.6760
# Train Fy R2: 0.9945 ± 0.0037
# Train Fz MAE: 0.3463 ± 0.1886
# Train Fz MSE: 0.5385 ± 0.4785
# Train Fz R2: 0.9973 ± 0.0026
# Test Fx MAE: 0.9660 ± 0.3987
# Test Fx MSE: 2.6932 ± 1.8961
# Test Fx R2: 0.9623 ± 0.0350
# Test Fy MAE: 1.2001 ± 0.7461
# Test Fy MSE: 6.3526 ± 6.5692
# Test Fy R2: 0.9002 ± 0.1196
# Test Fz MAE: 1.1341 ± 0.6898
# Test Fz MSE: 5.0448 ± 5.0341
# Test Fz R2: 0.9604 ± 0.0492
#
#
# ../../../data/22022021/13
# Droping 0 data points by null features
# X: (17994, 4), Y: (17994, 24)
# Train -> X: (12596, 4), Y: (12596, 24)
# Test -> X: (5398, 4), Y: (5398, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43814889 0.38132791 0.22569584 0.36115833],
#  std: [0.33994568 0.20526975 0.30426655 0.24717786]
#
# Test ->
#  min: [ 9.39139094e-04  4.01629872e-02 -6.41547701e-05 -4.70451929e-01],
#  max: [0.99931534 1.00496129 1.01123867 1.03661373],
#  mean: [0.44615867 0.39532071 0.23192119 0.32991565],
#  std: [0.34259714 0.21033286 0.31052329 0.27552888]
#
# Training time: 2.4514
# Train Fx MAE: 0.2671 ± 0.0813
# Train Fx MSE: 0.1725 ± 0.0852
# Train Fx R2: 0.9978 ± 0.0024
# Train Fy MAE: 0.3508 ± 0.2192
# Train Fy MSE: 0.4079 ± 0.4927
# Train Fy R2: 0.9960 ± 0.0031
# Train Fz MAE: 0.4101 ± 0.2316
# Train Fz MSE: 0.5961 ± 0.5963
# Train Fz R2: 0.9970 ± 0.0032
# Test Fx MAE: 2.1255 ± 0.6111
# Test Fx MSE: 12.8092 ± 7.2890
# Test Fx R2: 0.7648 ± 0.2853
# Test Fy MAE: 3.1269 ± 1.9184
# Test Fy MSE: 51.8325 ± 76.2630
# Test Fy R2: 0.4774 ± 0.3197
# Test Fz MAE: 4.5869 ± 2.9127
# Test Fz MSE: 74.3729 ± 82.2486
# Test Fz R2: 0.2056 ± 1.1495
#
#
# ../../../data/22022021/14
# Droping 0 data points by null features
# X: (17949, 4), Y: (17949, 24)
# Train -> X: (12565, 4), Y: (12565, 24)
# Test -> X: (5384, 4), Y: (5384, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43577373 0.38225369 0.20706457 0.48754447],
#  std: [0.33838343 0.203844   0.2902565  0.21646778]
#
# Test ->
#  min: [ 2.98026209e-04 -6.47079415e-04 -4.97419451e-05 -5.04867498e-03],
#  max: [0.99947119 0.99856191 1.00170457 0.98605629],
#  mean: [0.44507919 0.38680769 0.21351047 0.4774233 ],
#  std: [0.34094846 0.20378296 0.29565566 0.2173454 ]
#
# Training time: 2.4800
# Train Fx MAE: 0.3084 ± 0.1133
# Train Fx MSE: 0.3391 ± 0.2246
# Train Fx R2: 0.9925 ± 0.0078
# Train Fy MAE: 0.3737 ± 0.2810
# Train Fy MSE: 0.5939 ± 0.9494
# Train Fy R2: 0.9921 ± 0.0051
# Train Fz MAE: 0.3245 ± 0.1406
# Train Fz MSE: 0.4376 ± 0.3299
# Train Fz R2: 0.9944 ± 0.0051
# Test Fx MAE: 1.0403 ± 0.4275
# Test Fx MSE: 2.3857 ± 1.8758
# Test Fx R2: 0.8664 ± 0.2115
# Test Fy MAE: 1.2683 ± 0.7553
# Test Fy MSE: 4.6167 ± 5.9106
# Test Fy R2: 0.8545 ± 0.1760
# Test Fz MAE: 1.0502 ± 0.4568
# Test Fz MSE: 2.6124 ± 1.8778
# Test Fz R2: 0.9581 ± 0.0391
#
#
# ../../../data/22022021/15
# Droping 0 data points by null features
# X: (17892, 4), Y: (17892, 24)
# Train -> X: (12525, 4), Y: (12525, 24)
# Test -> X: (5367, 4), Y: (5367, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43689066 0.38269085 0.2063669  0.46168131],
#  std: [0.33897174 0.19926903 0.29068203 0.20597887]
#
# Test ->
#  min: [ 2.12294531e-04  4.08268446e-04 -5.23978985e-05  2.48774954e-03],
#  max: [1.0000767  0.9858247  1.00838582 0.93588947],
#  mean: [0.44597658 0.38218187 0.21320428 0.46063203],
#  std: [0.34111334 0.2011648  0.29562464 0.20737059]
#
# Training time: 2.3849
# Train Fx MAE: 0.3592 ± 0.1038
# Train Fx MSE: 0.3599 ± 0.1905
# Train Fx R2: 0.9928 ± 0.0057
# Train Fy MAE: 0.4256 ± 0.3076
# Train Fy MSE: 0.6801 ± 0.9297
# Train Fy R2: 0.9927 ± 0.0039
# Train Fz MAE: 0.3790 ± 0.1611
# Train Fz MSE: 0.4191 ± 0.3036
# Train Fz R2: 0.9946 ± 0.0034
# Test Fx MAE: 2.4449 ± 0.8799
# Test Fx MSE: 16.6589 ± 10.8523
# Test Fx R2: 0.6904 ± 0.1664
# Test Fy MAE: 2.5715 ± 2.0434
# Test Fy MSE: 26.4716 ± 46.1096
# Test Fy R2: 0.7256 ± 0.2534
# Test Fz MAE: 2.8979 ± 1.3245
# Test Fz MSE: 20.9404 ± 16.6368
# Test Fz R2: 0.6860 ± 0.2391
#
#
# ../../../data/22022021/16
# Droping 0 data points by null features
# X: (17978, 4), Y: (17978, 24)
# Train -> X: (12585, 4), Y: (12585, 24)
# Test -> X: (5393, 4), Y: (5393, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43540101 0.39693028 0.21089884 0.4773652 ],
#  std: [0.33871516 0.19478636 0.29100344 0.228968  ]
#
# Test ->
#  min: [ 3.84782692e-05 -1.18872928e-02 -6.81252160e-05  4.76578477e-03],
#  max: [1.00058294 0.99823496 1.01304411 0.98555659],
#  mean: [0.44322735 0.40192927 0.21719987 0.46359564],
#  std: [0.34125635 0.19999407 0.29866753 0.22436866]
#
# Training time: 2.1396
# Train Fx MAE: 0.3052 ± 0.0864
# Train Fx MSE: 0.2837 ± 0.1570
# Train Fx R2: 0.9974 ± 0.0013
# Train Fy MAE: 0.3121 ± 0.2417
# Train Fy MSE: 0.3804 ± 0.5994
# Train Fy R2: 0.9948 ± 0.0027
# Train Fz MAE: 0.3334 ± 0.1477
# Train Fz MSE: 0.3538 ± 0.3007
# Train Fz R2: 0.9964 ± 0.0021
# Test Fx MAE: 1.6676 ± 0.4732
# Test Fx MSE: 8.1000 ± 4.2937
# Test Fx R2: 0.9205 ± 0.0231
# Test Fy MAE: 1.7755 ± 1.4445
# Test Fy MSE: 11.7485 ± 19.1462
# Test Fy R2: 0.8384 ± 0.0654
# Test Fz MAE: 1.9871 ± 0.7742
# Test Fz MSE: 11.8291 ± 7.9669
# Test Fz R2: 0.8630 ± 0.0811
#
#
# ../../../data/22022021/17
# Droping 0 data points by null features
# X: (17907, 4), Y: (17907, 24)
# Train -> X: (12535, 4), Y: (12535, 24)
# Test -> X: (5372, 4), Y: (5372, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43504814 0.42646333 0.20950787 0.47434229],
#  std: [0.33765895 0.18662892 0.292249   0.2137913 ]
#
# Test ->
#  min: [ 1.45673801e-05 -3.21939335e-03 -5.15661025e-05  2.63888243e-03],
#  max: [0.99890161 1.00009299 1.00387291 0.99987834],
#  mean: [0.44359182 0.43266166 0.21678541 0.46280051],
#  std: [0.33920533 0.19184943 0.29752271 0.21329768]
#
# Training time: 2.1754
# Train Fx MAE: 0.3068 ± 0.1166
# Train Fx MSE: 0.3091 ± 0.2092
# Train Fx R2: 0.9970 ± 0.0019
# Train Fy MAE: 0.3373 ± 0.3086
# Train Fy MSE: 0.5670 ± 1.0560
# Train Fy R2: 0.9941 ± 0.0028
# Train Fz MAE: 0.3811 ± 0.2031
# Train Fz MSE: 0.4678 ± 0.4579
# Train Fz R2: 0.9949 ± 0.0034
# Test Fx MAE: 1.3323 ± 0.4642
# Test Fx MSE: 5.4434 ± 3.2762
# Test Fx R2: 0.9418 ± 0.0332
# Test Fy MAE: 1.5092 ± 1.4740
# Test Fy MSE: 10.9175 ± 20.4385
# Test Fy R2: 0.9080 ± 0.0282
# Test Fz MAE: 1.9794 ± 1.0572
# Test Fz MSE: 9.5315 ± 8.0757
# Test Fz R2: 0.8752 ± 0.0978
#
#
# ../../../data/22022021/18
# Droping 0 data points by null features
# X: (17900, 4), Y: (17900, 24)
# Train -> X: (12530, 4), Y: (12530, 24)
# Test -> X: (5370, 4), Y: (5370, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43363195 0.43377225 0.20576796 0.47704718],
#  std: [0.33643721 0.18968875 0.28899558 0.19238845]
#
# Test ->
#  min: [ 6.62148895e-04 -1.61714206e-04 -5.71616356e-05  6.49556792e-03],
#  max: [0.99990037 0.99412696 0.99617129 0.99618677],
#  mean: [0.44311153 0.43946321 0.21271826 0.47442724],
#  std: [0.33808567 0.19330586 0.29411664 0.19492269]
#
# Training time: 2.1678
# Train Fx MAE: 0.3841 ± 0.1406
# Train Fx MSE: 0.3680 ± 0.2361
# Train Fx R2: 0.9953 ± 0.0030
# Train Fy MAE: 0.4076 ± 0.2726
# Train Fy MSE: 0.5226 ± 0.5925
# Train Fy R2: 0.9937 ± 0.0024
# Train Fz MAE: 0.4022 ± 0.1526
# Train Fz MSE: 0.4202 ± 0.2806
# Train Fz R2: 0.9957 ± 0.0030
# Test Fx MAE: 3.3153 ± 0.9910
# Test Fx MSE: 25.5911 ± 14.9920
# Test Fx R2: 0.6260 ± 0.1817
# Test Fy MAE: 3.5753 ± 2.3221
# Test Fy MSE: 38.3662 ± 44.2662
# Test Fy R2: 0.4547 ± 0.2334
# Test Fz MAE: 3.7196 ± 1.0477
# Test Fz MSE: 30.9364 ± 14.4396
# Test Fz R2: 0.3888 ± 0.6815
#
#
# ../../../data/22022021/19
# Droping 0 data points by null features
# X: (11960, 4), Y: (11960, 24)
# Train -> X: (8372, 4), Y: (8372, 24)
# Test -> X: (3588, 4), Y: (3588, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43760734 0.41574402 0.2050418  0.47299783],
#  std: [0.33602213 0.19684754 0.29015519 0.20936491]
#
# Test ->
#  min: [3.09927204e-04 7.00574092e-02 1.20213608e-07 2.67506517e-03],
#  max: [0.99926301 0.99609999 0.99619918 0.94634534],
#  mean: [0.4436274  0.41724797 0.21223076 0.4717274 ],
#  std: [0.34083717 0.19864572 0.29348066 0.20995525]
#
# Training time: 1.3596
# Train Fx MAE: 0.3311 ± 0.1003
# Train Fx MSE: 0.2661 ± 0.1469
# Train Fx R2: 0.9961 ± 0.0036
# Train Fy MAE: 0.3405 ± 0.2040
# Train Fy MSE: 0.3664 ± 0.3756
# Train Fy R2: 0.9954 ± 0.0016
# Train Fz MAE: 0.3779 ± 0.1450
# Train Fz MSE: 0.3538 ± 0.2404
# Train Fz R2: 0.9966 ± 0.0020
# Test Fx MAE: 1.7046 ± 0.5191
# Test Fx MSE: 5.9086 ± 3.2585
# Test Fx R2: 0.9180 ± 0.0591
# Test Fy MAE: 1.7054 ± 1.0236
# Test Fy MSE: 8.0151 ± 8.0115
# Test Fy R2: 0.8967 ± 0.0380
# Test Fz MAE: 2.1607 ± 0.8549
# Test Fz MSE: 9.2690 ± 6.3008
# Test Fz R2: 0.9004 ± 0.0600
#
#
# ../../../data/22022021/2
# Droping 0 data points by null features
# X: (17972, 4), Y: (17972, 24)
# Train -> X: (12581, 4), Y: (12581, 24)
# Test -> X: (5391, 4), Y: (5391, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.4361799  0.37416378 0.20834283 0.40116163],
#  std: [0.33930253 0.20542934 0.29142696 0.22391545]
#
# Test ->
#  min: [ 4.89497746e-04  5.49979336e-02 -5.83123464e-05 -1.07871175e-03],
#  max: [0.99677743 1.00872081 1.00065876 0.96461782],
#  mean: [0.44446487 0.3826854  0.21316897 0.39233191],
#  std: [0.3416264  0.20928135 0.29525141 0.22090991]
#
# Training time: 2.1387
# Train Fx MAE: 0.3253 ± 0.0896
# Train Fx MSE: 0.2585 ± 0.1215
# Train Fx R2: 0.9969 ± 0.0014
# Train Fy MAE: 0.4247 ± 0.2498
# Train Fy MSE: 0.5647 ± 0.6187
# Train Fy R2: 0.9966 ± 0.0014
# Train Fz MAE: 0.4165 ± 0.1610
# Train Fz MSE: 0.4610 ± 0.2854
# Train Fz R2: 0.9978 ± 0.0017
# Test Fx MAE: 1.1219 ± 0.3061
# Test Fx MSE: 2.5954 ± 1.3877
# Test Fx R2: 0.9669 ± 0.0150
# Test Fy MAE: 1.5763 ± 1.0674
# Test Fy MSE: 8.2024 ± 12.4518
# Test Fy R2: 0.9542 ± 0.0238
# Test Fz MAE: 1.5417 ± 0.6336
# Test Fz MSE: 5.5709 ± 3.5038
# Test Fz R2: 0.9725 ± 0.0218
#
#
# ../../../data/22022021/3
# Droping 0 data points by null features
# X: (17941, 4), Y: (17941, 24)
# Train -> X: (12559, 4), Y: (12559, 24)
# Test -> X: (5382, 4), Y: (5382, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.4369297  0.37016908 0.21209716 0.38741492],
#  std: [0.33911607 0.21309734 0.29512824 0.21286823]
#
# Test ->
#  min: [-3.19794500e-06  1.08498843e-03 -1.34940741e-05  3.32763561e-03],
#  max: [0.99816797 0.99332056 1.00362465 0.96845736],
#  mean: [0.44931241 0.3729491  0.2196405  0.38205139],
#  std: [0.33957665 0.21761256 0.30160116 0.21272866]
#
# Training time: 2.2261
# Train Fx MAE: 0.3179 ± 0.0803
# Train Fx MSE: 0.2472 ± 0.1069
# Train Fx R2: 0.9977 ± 0.0013
# Train Fy MAE: 0.3942 ± 0.2308
# Train Fy MSE: 0.5265 ± 0.5910
# Train Fy R2: 0.9975 ± 0.0012
# Train Fz MAE: 0.3367 ± 0.1374
# Train Fz MSE: 0.3163 ± 0.1955
# Train Fz R2: 0.9987 ± 0.0010
# Test Fx MAE: 1.3934 ± 0.3488
# Test Fx MSE: 5.4304 ± 3.1719
# Test Fx R2: 0.9556 ± 0.0153
# Test Fy MAE: 1.6701 ± 1.0145
# Test Fy MSE: 10.2597 ± 13.5714
# Test Fy R2: 0.9447 ± 0.0309
# Test Fz MAE: 1.6818 ± 0.6894
# Test Fz MSE: 8.3980 ± 5.5552
# Test Fz R2: 0.9687 ± 0.0201
#
#
# ../../../data/22022021/4
# Droping 0 data points by null features
# X: (17964, 4), Y: (17964, 24)
# Train -> X: (12575, 4), Y: (12575, 24)
# Test -> X: (5389, 4), Y: (5389, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43604075 0.3529286  0.20738825 0.40011652],
#  std: [0.33848891 0.21064159 0.29001845 0.21134249]
#
# Test ->
#  min: [-3.11106042e-04 -3.22614942e-02 -5.77198990e-05 -1.56192643e-02],
#  max: [0.99977192 1.00520322 1.00210893 0.92106524],
#  mean: [0.44446421 0.36913719 0.21358938 0.3764449 ],
#  std: [0.34067936 0.21535522 0.29576429 0.20458213]
#
# Training time: 2.0932
# Train Fx MAE: 0.3116 ± 0.1053
# Train Fx MSE: 0.3206 ± 0.2062
# Train Fx R2: 0.9967 ± 0.0030
# Train Fy MAE: 0.2796 ± 0.1148
# Train Fy MSE: 0.2573 ± 0.2192
# Train Fy R2: 0.9947 ± 0.0035
# Train Fz MAE: 0.4151 ± 0.1381
# Train Fz MSE: 0.4570 ± 0.2759
# Train Fz R2: 0.9964 ± 0.0043
# Test Fx MAE: 1.6951 ± 0.9801
# Test Fx MSE: 9.7202 ± 11.8944
# Test Fx R2: 0.7912 ± 0.3538
# Test Fy MAE: 1.1945 ± 0.6220
# Test Fy MSE: 4.9929 ± 5.5361
# Test Fy R2: 0.9020 ± 0.0502
# Test Fz MAE: 2.5621 ± 1.1446
# Test Fz MSE: 17.7533 ± 12.1223
# Test Fz R2: 0.7993 ± 0.2917
#
#
# ../../../data/22022021/5
# Droping 0 data points by null features
# X: (17974, 4), Y: (17974, 24)
# Train -> X: (12582, 4), Y: (12582, 24)
# Test -> X: (5392, 4), Y: (5392, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43493879 0.41030856 0.2074459  0.42320162],
#  std: [0.33736793 0.19723393 0.29110258 0.20982956]
#
# Test ->
#  min: [ 1.23647574e-04  9.27008966e-02 -5.08865446e-05  1.24501115e-02],
#  max: [1.00006619 0.99799131 1.00121028 0.97170689],
#  mean: [0.44359146 0.41505581 0.21284076 0.42184037],
#  std: [0.34006565 0.1984108  0.29496073 0.21183046]
#
# Training time: 2.1997
# Train Fx MAE: 0.2615 ± 0.0813
# ...
# Test Fx R2: 0.9355 ± 0.0446
# Test Fy MAE: 2.1299 ± 1.3031
# Test Fy MSE: 18.7665 ± 22.7400
# Test Fy R2: 0.9260 ± 0.0540
# Test Fz MAE: 2.3894 ± 1.1363
# Test Fz MSE: 22.6292 ± 25.0643
# Test Fz R2: 0.9480 ± 0.0248
#
#
# ../../../data/24022021/11
# Droping 2 data points by null features
# X: (17802, 4), Y: (17802, 24)
# Train -> X: (12462, 4), Y: (12462, 24)
# Test -> X: (5340, 4), Y: (5340, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43382359 0.57253285 0.20601126 0.45405588],
#  std: [0.34105068 0.21143739 0.29216294 0.18203437]
#
# Test ->
#  min: [-1.26417928e-04  2.23732078e-02  4.27847956e-07  1.18756415e-02],
#  max: [0.99827928 0.98887918 1.00014368 0.99560064],
#  mean: [0.44100027 0.5703914  0.21313581 0.45732962],
#  std: [0.34516572 0.21317196 0.2949393  0.18606567]
#
# Training time: 2.0854
# Train Fx MAE: 0.3389 ± 0.1003
# Train Fx MSE: 0.4036 ± 0.2853
# Train Fx R2: 0.9980 ± 0.0018
# Train Fy MAE: 0.4473 ± 0.3074
# Train Fy MSE: 0.9137 ± 1.0894
# Train Fy R2: 0.9975 ± 0.0018
# Train Fz MAE: 0.3701 ± 0.1334
# Train Fz MSE: 0.4542 ± 0.2524
# Train Fz R2: 0.9986 ± 0.0007
# Test Fx MAE: 0.9155 ± 0.2602
# Test Fx MSE: 2.7427 ± 2.5300
# Test Fx R2: 0.9841 ± 0.0199
# Test Fy MAE: 1.1660 ± 0.8050
# Test Fy MSE: 5.0349 ± 6.1445
# Test Fy R2: 0.9869 ± 0.0083
# Test Fz MAE: 1.1636 ± 0.4589
# Test Fz MSE: 3.8976 ± 3.2832
# Test Fz R2: 0.9907 ± 0.0040
#
#
# ../../../data/24022021/12
# Droping 2 data points by null features
# X: (18076, 4), Y: (18076, 24)
# Train -> X: (12654, 4), Y: (12654, 24)
# Test -> X: (5422, 4), Y: (5422, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43067185 0.56391641 0.20873468 0.43965783],
#  std: [0.34000375 0.20956854 0.29342686 0.17155623]
#
# Test ->
#  min: [ 3.79344269e-04  2.92670848e-02 -2.25117153e-05  6.43955553e-03],
#  max: [0.99303266 0.99202003 1.00025019 0.93431638],
#  mean: [0.43993566 0.55558221 0.21123882 0.44478358],
#  std: [0.34399565 0.21251515 0.29369944 0.17565476]
#
# Training time: 2.3008
# Train Fx MAE: 0.4339 ± 0.1356
# Train Fx MSE: 0.7485 ± 0.6559
# Train Fx R2: 0.9971 ± 0.0018
# Train Fy MAE: 0.5708 ± 0.3967
# Train Fy MSE: 1.8320 ± 2.4860
# Train Fy R2: 0.9960 ± 0.0031
# Train Fz MAE: 0.4776 ± 0.1489
# Train Fz MSE: 0.7375 ± 0.4291
# Train Fz R2: 0.9979 ± 0.0012
# Test Fx MAE: 0.9667 ± 0.2591
# Test Fx MSE: 2.0054 ± 0.9823
# Test Fx R2: 0.9910 ± 0.0052
# Test Fy MAE: 1.2643 ± 0.8427
# Test Fy MSE: 5.9438 ± 7.5737
# Test Fy R2: 0.9858 ± 0.0092
# Test Fz MAE: 1.3255 ± 0.4908
# Test Fz MSE: 3.5448 ± 2.1182
# Test Fz R2: 0.9898 ± 0.0057
#
#
# ../../../data/24022021/13
# Droping 2 data points by null features
# X: (17673, 4), Y: (17673, 24)
# Train -> X: (12372, 4), Y: (12372, 24)
# Test -> X: (5301, 4), Y: (5301, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.44008998 0.57015662 0.20711878 0.44046026],
#  std: [0.3373368  0.20741015 0.29204676 0.17799626]
#
# Test ->
#  min: [-3.42647740e-04  1.98395460e-02 -7.26442345e-06 -1.05716300e-02],
#  max: [1.00478593 1.00615072 0.99851141 0.97954678],
#  mean: [0.43642332 0.57087    0.2134676  0.44480301],
#  std: [0.34295047 0.2072985  0.29472705 0.18071651]
#
# Training time: 2.0603
# Train Fx MAE: 0.4130 ± 0.1460
# Train Fx MSE: 0.4961 ± 0.4173
# Train Fx R2: 0.9983 ± 0.0009
# Train Fy MAE: 0.6147 ± 0.4991
# Train Fy MSE: 2.0689 ± 3.4222
# Train Fy R2: 0.9970 ± 0.0024
# Train Fz MAE: 0.4569 ± 0.1452
# Train Fz MSE: 0.5670 ± 0.3194
# Train Fz R2: 0.9986 ± 0.0009
# Test Fx MAE: 1.7528 ± 0.6211
# Test Fx MSE: 7.1132 ± 5.5670
# Test Fx R2: 0.9752 ± 0.0121
# Test Fy MAE: 2.5347 ± 2.0347
# Test Fy MSE: 29.7626 ± 49.7300
# Test Fy R2: 0.9589 ± 0.0263
# Test Fz MAE: 2.2710 ± 0.6424
# Test Fz MSE: 11.7399 ± 5.9016
# Test Fz R2: 0.9688 ± 0.0180
#
#
# ../../../data/24022021/14
# Droping 2 data points by null features
# X: (17984, 4), Y: (17984, 24)
# Train -> X: (12589, 4), Y: (12589, 24)
# Test -> X: (5395, 4), Y: (5395, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43620349 0.58074253 0.2237729  0.43093336],
#  std: [0.33885768 0.17525779 0.30240961 0.16645905]
#
# Test ->
#  min: [-7.83612550e-04  1.90361596e-01 -5.32804171e-05  6.00508488e-02],
#  max: [0.99785558 0.92245632 1.0107928  0.89415499],
#  mean: [0.44302273 0.59167895 0.22976959 0.42593644],
#  std: [0.34233228 0.13946252 0.30876155 0.15272983]
#
# Training time: 2.2074
# Train Fx MAE: 0.4917 ± 0.1860
# Train Fx MSE: 0.9357 ± 0.6034
# Train Fx R2: 0.9969 ± 0.0025
# Train Fy MAE: 0.6479 ± 0.3466
# Train Fy MSE: 2.0053 ± 2.3143
# Train Fy R2: 0.9908 ± 0.0046
# Train Fz MAE: 0.7113 ± 0.4023
# Train Fz MSE: 2.8271 ± 3.9175
# Train Fz R2: 0.9949 ± 0.0040
# Test Fx MAE: 2.1550 ± 0.7835
# Test Fx MSE: 14.4770 ± 9.5381
# Test Fx R2: 0.9401 ± 0.0587
# Test Fy MAE: 2.9963 ± 1.6621
# Test Fy MSE: 34.1519 ± 41.9977
# Test Fy R2: 0.7448 ± 0.1999
# Test Fz MAE: 3.3993 ± 1.8478
# Test Fz MSE: 40.2919 ± 46.4821
# Test Fz R2: 0.9118 ± 0.0687
#
#
# ../../../data/24022021/15
# Droping 2 data points by null features
# X: (17918, 4), Y: (17918, 24)
# Train -> X: (12543, 4), Y: (12543, 24)
# Test -> X: (5375, 4), Y: (5375, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43755531 0.54862598 0.22784342 0.42551749],
#  std: [0.3391136  0.18841815 0.30826806 0.1741781 ]
#
# Test ->
#  min: [-1.66444886e-04  2.36803388e-02 -1.12738065e-05 -1.26508761e-02],
#  max: [0.99814712 1.02993476 1.00154083 0.9530995 ],
#  mean: [0.44646479 0.54620979 0.23467587 0.42920483],
#  std: [0.34112496 0.19134087 0.31272994 0.17732118]
#
# Training time: 2.2112
# Train Fx MAE: 0.2812 ± 0.1143
# Train Fx MSE: 0.2378 ± 0.2136
# Train Fx R2: 0.9992 ± 0.0007
# Train Fy MAE: 0.3904 ± 0.2214
# Train Fy MSE: 0.5889 ± 0.6287
# Train Fy R2: 0.9971 ± 0.0015
# Train Fz MAE: 0.3817 ± 0.2237
# Train Fz MSE: 0.6451 ± 0.7050
# Train Fz R2: 0.9989 ± 0.0010
# Test Fx MAE: 0.9140 ± 0.3558
# Test Fx MSE: 2.4568 ± 2.0949
# Test Fx R2: 0.9905 ± 0.0096
# Test Fy MAE: 1.2956 ± 0.8285
# Test Fy MSE: 7.5341 ± 9.4647
# Test Fy R2: 0.9647 ± 0.0244
# Test Fz MAE: 1.4368 ± 0.9936
# Test Fz MSE: 9.2092 ± 10.8973
# Test Fz R2: 0.9866 ± 0.0105
#
#
# ../../../data/24022021/16
# Droping 2 data points by null features
# X: (17918, 4), Y: (17918, 24)
# Train -> X: (12543, 4), Y: (12543, 24)
# Test -> X: (5375, 4), Y: (5375, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43755531 0.37976143 0.22784342 0.32905022],
#  std: [0.3391136  0.2184937  0.30826806 0.2564939 ]
#
# Test ->
#  min: [-1.66444886e-04 -6.97547692e-03 -1.12738065e-05  6.36387955e-03],
#  max: [0.99814712 0.98226951 1.00154083 0.98904683],
#  mean: [0.44646479 0.38307973 0.23467587 0.32045839],
#  std: [0.34112496 0.21905931 0.31272994 0.25202332]
#
# Training time: 2.2132
# Train Fx MAE: 0.2551 ± 0.1008
# Train Fx MSE: 0.1913 ± 0.1526
# Train Fx R2: 0.9993 ± 0.0006
# Train Fy MAE: 0.3528 ± 0.2065
# Train Fy MSE: 0.4928 ± 0.5527
# Train Fy R2: 0.9978 ± 0.0010
# Train Fz MAE: 0.3255 ± 0.1765
# Train Fz MSE: 0.5117 ± 0.5303
# Train Fz R2: 0.9990 ± 0.0009
# Test Fx MAE: 0.8742 ± 0.3324
# Test Fx MSE: 2.1485 ± 1.6053
# Test Fx R2: 0.9914 ± 0.0087
# Test Fy MAE: 1.2345 ± 0.7898
# Test Fy MSE: 6.5232 ± 8.1640
# Test Fy R2: 0.9629 ± 0.0375
# Test Fz MAE: 1.3214 ± 0.8569
# Test Fz MSE: 7.6183 ± 8.4482
# Test Fz R2: 0.9874 ± 0.0104
#
#
# ../../../data/24022021/2
# Droping 2 data points by null features
# X: (17979, 4), Y: (17979, 24)
# Train -> X: (12586, 4), Y: (12586, 24)
# Test -> X: (5393, 4), Y: (5393, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43608534 0.52231243 0.20688369 0.47598881],
#  std: [0.3392519  0.21408418 0.2902525  0.20048385]
#
# Test ->
#  min: [-1.39522321e-03  3.18962888e-03 -4.00364927e-05  2.46826559e-02],
#  max: [0.99979065 0.9205694  1.00155612 0.99844581],
#  mean: [0.44387401 0.51775235 0.21183392 0.47852681],
#  std: [0.34166781 0.21588887 0.29432224 0.20253625]
#
# Training time: 2.1485
# Train Fx MAE: 0.3295 ± 0.1322
# Train Fx MSE: 0.2856 ± 0.2324
# Train Fx R2: 0.9955 ± 0.0045
# Train Fy MAE: 0.4518 ± 0.3482
# Train Fy MSE: 0.8092 ± 1.0953
# Train Fy R2: 0.9945 ± 0.0022
# Train Fz MAE: 0.3665 ± 0.1612
# Train Fz MSE: 0.3231 ± 0.2067
# Train Fz R2: 0.9957 ± 0.0038
# Test Fx MAE: 1.1993 ± 0.5646
# Test Fx MSE: 3.3478 ± 2.7804
# Test Fx R2: 0.9512 ± 0.0452
# Test Fy MAE: 1.6393 ± 1.3120
# Test Fy MSE: 8.8440 ± 12.6095
# Test Fy R2: 0.9481 ± 0.0202
# Test Fz MAE: 1.6524 ± 1.0581
# Test Fz MSE: 6.0753 ± 6.1415
# Test Fz R2: 0.9335 ± 0.0609
#
#
# ../../../data/24022021/3
# Droping 2 data points by null features
# X: (17677, 4), Y: (17677, 24)
# Train -> X: (12374, 4), Y: (12374, 24)
# Test -> X: (5303, 4), Y: (5303, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.44075717 0.56365964 0.20843667 0.46769786],
#  std: [0.33894736 0.23441039 0.29242889 0.20618863]
#
# Test ->
#  min: [ 2.41554387e-04 -1.08115154e-02 -4.02158597e-06 -6.17528731e-03],
#  max: [1.00022621 1.00341038 0.99923907 1.00870321],
#  mean: [0.44034583 0.56600971 0.21573255 0.46504614],
#  std: [0.34295912 0.23738776 0.29562341 0.21049932]
#
# Training time: 2.1641
# Train Fx MAE: 0.3606 ± 0.1288
# Train Fx MSE: 0.3815 ± 0.2323
# Train Fx R2: 0.9942 ± 0.0047
# Train Fy MAE: 0.4936 ± 0.3784
# Train Fy MSE: 0.9104 ± 1.3238
# Train Fy R2: 0.9939 ± 0.0025
# Train Fz MAE: 0.3449 ± 0.1591
# Train Fz MSE: 0.3615 ± 0.2941
# Train Fz R2: 0.9957 ± 0.0039
# Test Fx MAE: 1.1764 ± 0.4375
# Test Fx MSE: 3.5998 ± 2.4820
# Test Fx R2: 0.9450 ± 0.0515
# Test Fy MAE: 1.6685 ± 1.2798
# Test Fy MSE: 9.1831 ± 12.1937
# Test Fy R2: 0.9434 ± 0.0233
# Test Fz MAE: 1.2233 ± 0.6170
# Test Fz MSE: 3.8616 ± 3.2443
# Test Fz R2: 0.9552 ± 0.0331
#
#
# ../../../data/24022021/4
# Droping 2 data points by null features
# X: (17956, 4), Y: (17956, 24)
# Train -> X: (12570, 4), Y: (12570, 24)
# Test -> X: (5386, 4), Y: (5386, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43506478 0.56275436 0.20542715 0.44562295],
#  std: [0.33904318 0.22700513 0.28932642 0.19308644]
#
# Test ->
#  min: [-1.12691067e-02  2.37325455e-02 -1.48601156e-05 -4.94603130e-03],
#  max: [0.999842   0.99859262 1.00680301 1.005295  ],
#  mean: [0.44370235 0.55725945 0.21208432 0.44755193],
#  std: [0.34140659 0.22706758 0.29510131 0.1943952 ]
#
# Training time: 2.2369
# Train Fx MAE: 0.5695 ± 0.2030
# Train Fx MSE: 1.0657 ± 0.6027
# Train Fx R2: 0.9920 ± 0.0047
# Train Fy MAE: 0.6021 ± 0.4465
# Train Fy MSE: 1.3195 ± 1.7767
# Train Fy R2: 0.9909 ± 0.0048
# Train Fz MAE: 0.5274 ± 0.2369
# Train Fz MSE: 0.8542 ± 0.5727
# Train Fz R2: 0.9904 ± 0.0089
# Test Fx MAE: 3.0379 ± 0.8399
# Test Fx MSE: 35.4419 ± 19.1187
# Test Fx R2: 0.6444 ± 0.2316
# Test Fy MAE: 3.4467 ± 2.1653
# Test Fy MSE: 37.1699 ± 42.7150
# Test Fy R2: 0.2356 ± 0.9884
# Test Fz MAE: 3.1607 ± 1.3984
# Test Fz MSE: 30.5255 ± 19.9552
# Test Fz R2: -0.2355 ± 2.5797
#
#
# ../../../data/24022021/5
# Droping 2 data points by null features
# X: (17746, 4), Y: (17746, 24)
# Train -> X: (12423, 4), Y: (12423, 24)
# Test -> X: (5323, 4), Y: (5323, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43947181 0.56617724 0.20807335 0.44353471],
#  std: [0.33864955 0.22954707 0.29283166 0.19227323]
#
# Test ->
#  min: [ 1.36030996e-04  1.74986323e-02  2.19687621e-06 -2.59355288e-03],
#  max: [1.0000422  1.00862397 1.00044698 0.99718698],
#  mean: [0.44377438 0.56640405 0.21573098 0.44400464],
#  std: [0.34378173 0.22773952 0.29601806 0.19459417]
#
# Training time: 2.1669
# Train Fx MAE: 0.3815 ± 0.1249
# Train Fx MSE: 0.4650 ± 0.2765
# Train Fx R2: 0.9966 ± 0.0022
# Train Fy MAE: 0.4955 ± 0.3902
# Train Fy MSE: 0.9389 ± 1.4267
# Train Fy R2: 0.9932 ± 0.0043
# Train Fz MAE: 0.3717 ± 0.1607
# Train Fz MSE: 0.4078 ± 0.2501
# Train Fz R2: 0.9950 ± 0.0049
# Test Fx MAE: 0.9684 ± 0.3282
# Test Fx MSE: 2.3654 ± 1.4145
# Test Fx R2: 0.9815 ± 0.0131
# Test Fy MAE: 1.3809 ± 1.1688
# Test Fy MSE: 6.9496 ± 12.6110
# Test Fy R2: 0.9557 ± 0.0248
# Test Fz MAE: 0.9968 ± 0.4879
# Test Fz MSE: 2.6102 ± 2.0150
# Test Fz R2: 0.9739 ± 0.0212
#
#
# ../../../data/24022021/6
# Droping 2 data points by null features
# X: (18024, 4), Y: (18024, 24)
# Train -> X: (12617, 4), Y: (12617, 24)
# Test -> X: (5407, 4), Y: (5407, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43445203 0.51999793 0.20777404 0.4408611 ],
#  std: [0.3387667  0.21694733 0.29170063 0.19190704]
#
# Test ->
#  min: [ 7.27541003e-05  8.98389612e-04 -8.25756518e-05 -8.92139899e-03],
#  max: [1.00031965 0.96407592 0.99973046 0.98826409],
#  mean: [0.44257725 0.51476417 0.21278591 0.44246685],
#  std: [0.3412538  0.2176729  0.29523263 0.19270259]
#
# Training time: 2.2265
# Train Fx MAE: 0.3436 ± 0.1090
# Train Fx MSE: 0.3094 ± 0.1717
# Train Fx R2: 0.9974 ± 0.0021
# Train Fy MAE: 0.4819 ± 0.3965
# Train Fy MSE: 0.8514 ± 1.4465
# Train Fy R2: 0.9949 ± 0.0030
# Train Fz MAE: 0.3655 ± 0.1823
# Train Fz MSE: 0.3469 ± 0.2456
# Train Fz R2: 0.9968 ± 0.0022
# Test Fx MAE: 1.1694 ± 0.4003
# Test Fx MSE: 3.9352 ± 2.5147
# Test Fx R2: 0.9700 ± 0.0225
# Test Fy MAE: 1.6099 ± 1.2362
# Test Fy MSE: 9.2454 ± 14.3223
# Test Fy R2: 0.9362 ± 0.0459
# Test Fz MAE: 1.5020 ± 0.8278
# Test Fz MSE: 5.7610 ± 4.4229
# Test Fz R2: 0.9413 ± 0.0546
#
#
# ../../../data/24022021/7
# Droping 2 data points by null features
# X: (17767, 4), Y: (17767, 24)
# Train -> X: (12437, 4), Y: (12437, 24)
# Test -> X: (5330, 4), Y: (5330, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.44027515 0.57797643 0.22640968 0.41825578],
#  std: [0.33914058 0.22454253 0.30411817 0.19688431]
#
# Test ->
#  min: [5.81831469e-04 1.80135167e-02 2.40177402e-06 1.10241614e-03],
#  max: [0.99655631 0.98655282 1.01533163 0.95440312],
#  mean: [0.44632421 0.57232572 0.2376568  0.42133432],
#  std: [0.34389297 0.22093325 0.31388048 0.19409225]
#
# Training time: 2.3080
# Train Fx MAE: 0.4576 ± 0.2263
# Train Fx MSE: 1.1421 ± 1.3602
# Train Fx R2: 0.9959 ± 0.0031
# Train Fy MAE: 0.5054 ± 0.3334
# Train Fy MSE: 1.1820 ± 1.3598
# Train Fy R2: 0.9914 ± 0.0051
# Train Fz MAE: 0.6931 ± 0.4513
# Train Fz MSE: 1.9681 ± 1.8238
# Train Fz R2: 0.9919 ± 0.0078
# Test Fx MAE: 2.0853 ± 1.5917
# Test Fx MSE: 29.6451 ± 58.1068
# Test Fx R2: 0.8851 ± 0.1359
# Test Fy MAE: 1.9583 ± 1.1605
# Test Fy MSE: 14.6869 ± 15.1406
# Test Fy R2: 0.8226 ± 0.1277
# Test Fz MAE: 3.6814 ± 2.3379
# Test Fz MSE: 67.3462 ± 67.8791
# Test Fz R2: 0.4812 ± 0.6739
#
#
# ../../../data/24022021/8
# Droping 2 data points by null features
# X: (18041, 4), Y: (18041, 24)
# Train -> X: (12629, 4), Y: (12629, 24)
# Test -> X: (5412, 4), Y: (5412, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43506034 0.56985682 0.23541615 0.41279878],
#  std: [0.33956589 0.22424986 0.3116699  0.19424353]
#
# Test ->
#  min: [-4.59928979e-05  1.27395734e-04 -7.40498698e-05  5.90991418e-04],
#  max: [0.99973796 0.9970115  1.01659292 0.9454195 ],
#  mean: [0.44380624 0.56255735 0.24277479 0.41521703],
#  std: [0.34265969 0.22699444 0.31938414 0.19805507]
#
# Training time: 2.3052
# Train Fx MAE: 0.3549 ± 0.1362
# Train Fx MSE: 0.4290 ± 0.2651
# Train Fx R2: 0.9982 ± 0.0016
# Train Fy MAE: 0.4456 ± 0.2914
# Train Fy MSE: 0.8535 ± 1.0155
# Train Fy R2: 0.9941 ± 0.0051
# Train Fz MAE: 0.4902 ± 0.2750
# Train Fz MSE: 0.9561 ± 0.8738
# Train Fz R2: 0.9967 ± 0.0026
# Test Fx MAE: 2.3815 ± 0.9332
# Test Fx MSE: 16.5801 ± 10.9095
# Test Fx R2: 0.9368 ± 0.0559
# Test Fy MAE: 2.7977 ± 2.0255
# Test Fy MSE: 27.1923 ± 35.9164
# Test Fy R2: 0.8090 ± 0.1640
# Test Fz MAE: 3.4680 ± 2.2580
# Test Fz MSE: 40.6370 ± 46.1815
# Test Fz R2: 0.8818 ± 0.0957
#
#
# ../../../data/24022021/9
# Droping 2 data points by null features
# X: (18035, 4), Y: (18035, 24)
# Train -> X: (12625, 4), Y: (12625, 24)
# Test -> X: (5410, 4), Y: (5410, 24)
# Train ->
#  min: [0. 0. 0. 0.],
#  max: [1. 1. 1. 1.],
#  mean: [0.43489986 0.5681924  0.23814989 0.42369944],
#  std: [0.33974371 0.22401884 0.31325606 0.19985675]
#
# Test ->
#  min: [-2.69288318e-04 -4.19843013e-04 -8.71344020e-05  7.32937407e-03],
#  max: [0.99997567 0.98277785 1.01539995 0.97995312],
#  mean: [0.4433564  0.5606747  0.2461469  0.42755027],
#  std: [0.34274433 0.2226267  0.32158279 0.19998189]
#
# Training time: 2.2881
# Train Fx MAE: 0.3249 ± 0.1193
# Train Fx MSE: 0.3288 ± 0.2500
# Train Fx R2: 0.9987 ± 0.0012
# Train Fy MAE: 0.4584 ± 0.3163
# Train Fy MSE: 0.8318 ± 1.0110
# Train Fy R2: 0.9953 ± 0.0033
# Train Fz MAE: 0.4518 ± 0.2437
# Train Fz MSE: 0.7561 ± 0.6726
# Train Fz R2: 0.9980 ± 0.0016
# Test Fx MAE: 2.8330 ± 1.3846
# Test Fx MSE: 28.4589 ± 31.6163
# Test Fx R2: 0.9249 ± 0.0432
# Test Fy MAE: 3.3895 ± 2.6055
# Test Fy MSE: 45.4408 ± 65.4654
# Test Fy R2: 0.7872 ± 0.1215
# Test Fz MAE: 4.6679 ± 3.2997
# Test Fz MSE: 82.7055 ± 104.7002
# Test Fz R2: 0.8581 ± 0.0842

# %%
# Display the score mean and standard deviation of each axis
for subset in ['Train', 'Test']:
    for f, force in enumerate(['Fx', 'Fy', 'Fz']):
        for loss in ['MAE', 'MSE', 'R2']:
            scores = results_full[' '.join([subset, force, loss])]
            s_mean = np.mean(scores)
            s_median = np.median(scores)
            s_std = np.std(scores)

            print(' '.join([subset, force, loss]) + ': {:.4f} ± {:.4f}'.format(s_mean, s_std))            
            print(' '.join([subset, force, loss, '(median)']) + ': {:.4f}'.format(s_median))
# Out:
# Train Fx MAE: 0.3431 ± 0.0769
# Train Fx MAE (median): 0.3249
# Train Fx MSE: 0.3899 ± 0.2893
# Train Fx MSE (median): 0.3106
# Train Fx R2: 0.9960 ± 0.0023
# Train Fx R2 (median): 0.9967
# Train Fy MAE: 0.3976 ± 0.1025
# Train Fy MAE (median): 0.3731
# Train Fy MSE: 0.6575 ± 0.5049
# Train Fy MSE (median): 0.5187
# Train Fy R2: 0.9942 ± 0.0026
# Train Fy R2 (median): 0.9945
# Train Fz MAE: 0.3990 ± 0.1093
# Train Fz MAE (median): 0.3779
# Train Fz MSE: 0.5991 ± 0.5781
# Train Fz MSE (median): 0.4542
# Train Fz R2: 0.9962 ± 0.0020
# Train Fz R2 (median): 0.9967
# Test Fx MAE: 1.6884 ± 1.2286
# Test Fx MAE (median): 1.2379
# Test Fx MSE: 15.3234 ± 48.4273
# Test Fx MSE (median): 4.4948
# Test Fx R2: 0.8632 ± 0.2022
# Test Fx R2 (median): 0.9401
# Test Fy MAE: 1.7936 ± 0.9042
# Test Fy MAE (median): 1.3809
# Test Fy MSE: 15.9894 ± 23.7354
# Test Fy MSE (median): 6.9496
# Test Fy R2: 0.7606 ± 0.4480
# Test Fy R2 (median): 0.9121
# Test Fz MAE: 2.1861 ± 1.5952
# Test Fz MAE (median): 1.5020
# Test Fz MSE: 27.0706 ± 72.3742
# Test Fz MSE (median): 6.0753
# Test Fz R2: 0.7753 ± 0.4589
# Test Fz R2 (median): 0.9463
